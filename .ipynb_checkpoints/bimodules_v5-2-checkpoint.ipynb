# %%
from IPython.display import Image
from os import chdir
import numpy as np
import gudhi as gd
import matplotlib.pyplot as plt
import matplotlib

# %%
# read the file
file_name = "function_rips_with_threshold_1000_1"
#file_name="fig3-2"

rank_dim = 0

simplices = []
vertice_id = 0
i = 0

x_values = []
y_values = []

for line in open("../cgta_paper_2021/function_rips/"+file_name+".scc"):
#for line in open("./data/"+file_name+".txt"):
    if(line[0]!='#'):
        
        if(i<=1):
            i=i+1
            continue
            
        elif(i==2):
            rank_num=[] # sizes of generating sets
            for j in line.split():
                rank_num.append(int(j))
            i=i+1
            rank_num=rank_num[:-1]
            print("rank_num=",rank_num)
        else:
            block = line.split(';')
            grid = block[0].split()
            grid_x = float(grid[0])
            grid_y = float(grid[1])
            #grid_x = int(float(grid[0])*20)
            #grid_y = int(float(grid[1])*20)
            x_values.append(grid_x)
            y_values.append(grid_y)
            
            
            if len(block)>1:
                face = block[1].split()
                for j in range(len(face)):
                    face[j] = int(face[j])
                simplices.append([grid_x,grid_y,face])
                
            else:
                simplices.append([grid_x,grid_y,[vertice_id]])
                vertice_id += 1
            i=i+1   




simplex_tree = []
start_id=0
for i in range(len(rank_num)-1,-1,-1):
    simplices_i=[]
    for j in range(len(simplices)-start_id-rank_num[i],len(simplices)-start_id):
        simplices_i.append(simplices[j])
    start_id += rank_num[i]
    simplex_tree.append(simplices_i)
    


#transform face number to vertex number
for i in range(1,len(simplex_tree)):
    for j in range(len(simplex_tree[i])):
        simplex = simplex_tree[i][j]
        face = simplex[2]
        vertices=[]
        for face_id in face:
            vert = simplex_tree[i-1][face_id][2]
            for vert_id in vert:
                if vert_id not in vertices:
                    vertices.append(vert_id)
        simplex_tree[i][j][2]=vertices



## To verify the data structur
## simplices contain all the information we need
#print("the simplex tree:")
#for i in range(len(simplex_tree)):
#    for simplex in simplex_tree[i]:
#        print(simplex)
# Out:
# rank_num= [447, 347, 181, 50]

# %%
x_values_ordered = sorted(list({}.fromkeys(x_values).keys()))
y_values_ordered = sorted(list({}.fromkeys(y_values).keys()))


simplex_tree_integer=simplex_tree

for i in range(len(simplex_tree_integer)):
    for j in range(len(simplex_tree_integer[i])):
        simplex_tree_integer[i][j][0]=x_values_ordered.index(simplex_tree_integer[i][j][0])
        simplex_tree_integer[i][j][1]=y_values_ordered.index(simplex_tree_integer[i][j][1])

# %%
x_range=len(x_values_ordered)-1
y_range=len(y_values_ordered)-1

end_point = [x_range,y_range]
print("end_point ",end_point)
# Out:
# end_point  [181, 11]

# %% [markdown]
# ## Compute rank invariant

# %%
def create_stair(elbow, end_point):
    # stair a path passing through the elbow.
    stair = []
    
    if(elbow[0]==0 or elbow[1]==end_point[1]):
        for i in range(end_point[1]+1):
            stair.append([0,i])
        for j in range(1,end_point[0]+1):
            stair.append([j,i])
    else:
        for i in range(elbow[1]+1):
            stair.append([0,i])   # i=0
        for j in range(elbow[0]):
            stair.append([j+1,i]) # j=0
        for k in range(i+1, end_point[1]+1):
            stair.append([j+1,k]) # k=2,3
        for l in range(j+2, end_point[0]+1):
            stair.append([l,k])
    return stair

def compute_rk(i,j,k,l,barcodes,rank_dim):
# This function computes the value rank(s,t) where s=(i,j) and t = (k,l)
    if(i>k or j>l):
        return 0
    
    s_1 = i + j
    t_1 = k + l
    rank0_inv = 0
    rank1_inv = 0

    for barcode in barcodes:
        if(barcode[0]==0):
            if(barcode[1][0]<=s_1 and barcode[1][1]>t_1):
                rank0_inv = rank0_inv + 1
        elif(barcode[0]==1):
            if(barcode[1][0]<=s_1 and barcode[1][1]>t_1):
                rank1_inv = rank1_inv + 1
    if(rank_dim==0):
        return rank0_inv
    elif(rank_dim==1):
        return rank1_inv

# %%
import time
#grid is from (0,0)
#vertex index is from 1
rank_inv = np.array(np.zeros((x_range+1,y_range+1,x_range+1,y_range+1)))

st = gd.SimplexTree()
#result_rank_fn="./result/rank1_invariance_for_"+file_name+".txt"
#f_rank = f.open(result_rank_fn,"w")



#Scan all the elbows
for i in range(x_range+1):
    for j in range(y_range+1):
        elbow = [i,j]
        print("elbow",elbow)
        start_time=time.time()
        #print("time: start building a simplex tree",time.time())
        stair = create_stair(elbow, end_point)
        #print("stair",stair)

        # Build the simplex tree
        
        for ii in range(len(simplex_tree_integer)):
            for jj in range(len(simplex_tree_integer[ii])):
                simplex = simplex_tree_integer[ii][jj]
                for grid_id in stair:
                    if simplex[0]<=grid_id[0] and simplex[1]<=grid_id[1]:
                        filtration_value = grid_id[0]+grid_id[1] #TODO
                        #print("time enter insert/assign ", time.asctime( time.localtime(time.time())))
                        if((st.insert(simplex[2], filtration = filtration_value))==False): #TODO:optimize with C++, we don't have the funciton for Python
                            #print("time finish insert",time.asctime( time.localtime(time.time())))
                            st.assign_filtration(simplex[2], filtration = filtration_value)
                        break
                        
        st_time=time.time()                
        print("time of building a simplex tree",st_time-start_time,"s")
        
        #st_gen = st.get_filtration() 
        #for splx in st_gen :
        #    print(splx)
        
        barcodes = st.persistence()
        #print("barcodes,",barcodes)
        bc_time =time.time()
        print("time of calculating barcodes ",bc_time-st_time,"s")
        
        for start_id in range(len(stair)):
            for end_id in range(start_id,len(stair)):
                grid_start = stair[start_id]
                grid_end = stair[end_id]
                [ri,rj,rk,rl]=[grid_start[0],grid_start[1],grid_end[0],grid_end[1]]
                #print("[ri,rj,rk,rl]=",[ri,rj,rk,rl])
                rank_inv[ri,rj,rk,rl]=compute_rk(ri,rj,rk,rl,barcodes,rank_dim)
        ri_time = time.time()
        print("time of finishing calculating rank invariance",ri_time-bc_time,"s")
        print("total time for one elbow ",ri_time-start_time,"s")
# Out:
# elbow [0, 0]
# time of building a simplex tree 0.013586997985839844 s
# time of calculating barcodes  0.0006239414215087891 s
# time of finishing calculating rank invariance 0.20768308639526367 s
# total time for one elbow  0.2218940258026123 s
# elbow [0, 1]
# time of building a simplex tree 0.014199018478393555 s
# time of calculating barcodes  0.0006668567657470703 s
# time of finishing calculating rank invariance 0.22723913192749023 s
# total time for one elbow  0.24210500717163086 s
# elbow [0, 2]
# time of building a simplex tree 0.016305923461914062 s
# time of calculating barcodes  0.001165151596069336 s
# time of finishing calculating rank invariance 0.2157900333404541 s
# total time for one elbow  0.2332611083984375 s
# elbow [0, 3]
# time of building a simplex tree 0.014243125915527344 s
# time of calculating barcodes  0.0007271766662597656 s
# time of finishing calculating rank invariance 0.1971299648284912 s
# total time for one elbow  0.21210026741027832 s
# elbow [0, 4]
# time of building a simplex tree 0.014132976531982422 s
# time of calculating barcodes  0.0009160041809082031 s
# time of finishing calculating rank invariance 0.19762706756591797 s
# total time for one elbow  0.2126760482788086 s
# elbow [0, 5]
# time of building a simplex tree 0.014965057373046875 s
# time of calculating barcodes  0.0010190010070800781 s
# time of finishing calculating rank invariance 0.2128920555114746 s
# total time for one elbow  0.22887611389160156 s
# elbow [0, 6]
# time of building a simplex tree 0.01544189453125 s
# time of calculating barcodes  0.0006802082061767578 s
# time of finishing calculating rank invariance 0.2190699577331543 s
# total time for one elbow  0.23519206047058105 s
# elbow [0, 7]
# time of building a simplex tree 0.015285968780517578 s
# time of calculating barcodes  0.0006091594696044922 s
# time of finishing calculating rank invariance 0.20688986778259277 s
# total time for one elbow  0.22278499603271484 s
# elbow [0, 8]
# time of building a simplex tree 0.013660907745361328 s
# time of calculating barcodes  0.0007250308990478516 s
# time of finishing calculating rank invariance 0.19765019416809082 s
# total time for one elbow  0.2120361328125 s
# elbow [0, 9]
# time of building a simplex tree 0.013882160186767578 s
# time of calculating barcodes  0.0008530616760253906 s
# time of finishing calculating rank invariance 0.2087547779083252 s
# total time for one elbow  0.22348999977111816 s
# elbow [0, 10]
# time of building a simplex tree 0.01676177978515625 s
# time of calculating barcodes  0.0006999969482421875 s
# time of finishing calculating rank invariance 0.21608805656433105 s
# total time for one elbow  0.2335498332977295 s
# elbow [0, 11]
# time of building a simplex tree 0.01450204849243164 s
# time of calculating barcodes  0.0007870197296142578 s
# time of finishing calculating rank invariance 0.21738076210021973 s
# total time for one elbow  0.23266983032226562 s
# elbow [1, 0]
# time of building a simplex tree 0.015495061874389648 s
# time of calculating barcodes  0.0008981227874755859 s
# time of finishing calculating rank invariance 0.20376873016357422 s
# total time for one elbow  0.22016191482543945 s
# elbow [1, 1]
# time of building a simplex tree 0.01440572738647461 s
# time of calculating barcodes  0.0006792545318603516 s
# time of finishing calculating rank invariance 0.20297789573669434 s
# total time for one elbow  0.2180628776550293 s
# elbow [1, 2]
# time of building a simplex tree 0.01382589340209961 s
# time of calculating barcodes  0.0009369850158691406 s
# time of finishing calculating rank invariance 0.19600486755371094 s
# total time for one elbow  0.2107677459716797 s
# elbow [1, 3]
# time of building a simplex tree 0.014441967010498047 s
# time of calculating barcodes  0.000762939453125 s
# time of finishing calculating rank invariance 0.20036697387695312 s
# total time for one elbow  0.21557188034057617 s
# elbow [1, 4]
# time of building a simplex tree 0.014554738998413086 s
# time of calculating barcodes  0.0010161399841308594 s
# time of finishing calculating rank invariance 0.20477581024169922 s
# total time for one elbow  0.22034668922424316 s
# elbow [1, 5]
# time of building a simplex tree 0.01389002799987793 s
# time of calculating barcodes  0.0007128715515136719 s
# time of finishing calculating rank invariance 0.19742798805236816 s
# total time for one elbow  0.21203088760375977 s
# elbow [1, 6]
# time of building a simplex tree 0.014003992080688477 s
# time of calculating barcodes  0.0011081695556640625 s
# time of finishing calculating rank invariance 0.20058989524841309 s
# total time for one elbow  0.21570205688476562 s
# elbow [1, 7]
# time of building a simplex tree 0.014012813568115234 s
# time of calculating barcodes  0.0011069774627685547 s
# time of finishing calculating rank invariance 0.202254056930542 s
# total time for one elbow  0.21737384796142578 s
# elbow [1, 8]
# time of building a simplex tree 0.014187812805175781 s
# time of calculating barcodes  0.0013210773468017578 s
# time of finishing calculating rank invariance 0.2183818817138672 s
# total time for one elbow  0.23389077186584473 s
# elbow [1, 9]
# time of building a simplex tree 0.014427900314331055 s
# time of calculating barcodes  0.0007550716400146484 s
# time of finishing calculating rank invariance 0.20339512825012207 s
# total time for one elbow  0.21857810020446777 s
# elbow [1, 10]
# time of building a simplex tree 0.013611078262329102 s
# time of calculating barcodes  0.0007710456848144531 s
# time of finishing calculating rank invariance 0.19742703437805176 s
# total time for one elbow  0.2118091583251953 s
# elbow [1, 11]
# time of building a simplex tree 0.01665186882019043 s
# time of calculating barcodes  0.0008211135864257812 s
# time of finishing calculating rank invariance 0.20783686637878418 s
# total time for one elbow  0.2253098487854004 s
# elbow [2, 0]
# time of building a simplex tree 0.01534414291381836 s
# time of calculating barcodes  0.0006399154663085938 s
# time of finishing calculating rank invariance 0.20292305946350098 s
# total time for one elbow  0.21890711784362793 s
# elbow [2, 1]
# time of building a simplex tree 0.013854026794433594 s
# time of calculating barcodes  0.0008590221405029297 s
# time of finishing calculating rank invariance 0.19240188598632812 s
# total time for one elbow  0.20711493492126465 s
# elbow [2, 2]
# time of building a simplex tree 0.014552831649780273 s
# time of calculating barcodes  0.0014541149139404297 s
# time of finishing calculating rank invariance 0.19205927848815918 s
# total time for one elbow  0.20806622505187988 s
# elbow [2, 3]
# time of building a simplex tree 0.013900995254516602 s
# time of calculating barcodes  0.0008161067962646484 s
# time of finishing calculating rank invariance 0.19225192070007324 s
# total time for one elbow  0.2069690227508545 s
# elbow [2, 4]
# time of building a simplex tree 0.015146017074584961 s
# time of calculating barcodes  0.0007872581481933594 s
# time of finishing calculating rank invariance 0.19626379013061523 s
# total time for one elbow  0.21219706535339355 s
# elbow [2, 5]
# time of building a simplex tree 0.014706134796142578 s
# time of calculating barcodes  0.0011038780212402344 s
# time of finishing calculating rank invariance 0.1963810920715332 s
# total time for one elbow  0.21219110488891602 s
# elbow [2, 6]
# time of building a simplex tree 0.019692182540893555 s
# time of calculating barcodes  0.0010988712310791016 s
# time of finishing calculating rank invariance 0.19405603408813477 s
# total time for one elbow  0.21484708786010742 s
# elbow [2, 7]
# time of building a simplex tree 0.013904809951782227 s
# time of calculating barcodes  0.0007281303405761719 s
# time of finishing calculating rank invariance 0.19412899017333984 s
# total time for one elbow  0.20876193046569824 s
# elbow [2, 8]
# time of building a simplex tree 0.01388692855834961 s
# time of calculating barcodes  0.0006611347198486328 s
# time of finishing calculating rank invariance 0.19418787956237793 s
# total time for one elbow  0.20873594284057617 s
# elbow [2, 9]
# time of building a simplex tree 0.014184951782226562 s
# time of calculating barcodes  0.0007617473602294922 s
# time of finishing calculating rank invariance 0.19541215896606445 s
# total time for one elbow  0.2103588581085205 s
# elbow [2, 10]
# time of building a simplex tree 0.013956069946289062 s
# time of calculating barcodes  0.0012459754943847656 s
# time of finishing calculating rank invariance 0.19315505027770996 s
# total time for one elbow  0.2083570957183838 s
# elbow [2, 11]
# time of building a simplex tree 0.01391911506652832 s
# time of calculating barcodes  0.0010521411895751953 s
# time of finishing calculating rank invariance 0.21716666221618652 s
# total time for one elbow  0.23213791847229004 s
# elbow [3, 0]
# time of building a simplex tree 0.01465606689453125 s
# time of calculating barcodes  0.0008988380432128906 s
# time of finishing calculating rank invariance 0.19739007949829102 s
# total time for one elbow  0.21294498443603516 s
# elbow [3, 1]
# time of building a simplex tree 0.017263174057006836 s
# time of calculating barcodes  0.0007717609405517578 s
# time of finishing calculating rank invariance 0.20664501190185547 s
# total time for one elbow  0.22467994689941406 s
# elbow [3, 2]
# time of building a simplex tree 0.01516103744506836 s
# time of calculating barcodes  0.0007481575012207031 s
# time of finishing calculating rank invariance 0.20850682258605957 s
# total time for one elbow  0.22441601753234863 s
# elbow [3, 3]
# time of building a simplex tree 0.014617919921875 s
# time of calculating barcodes  0.0008161067962646484 s
# time of finishing calculating rank invariance 0.21822905540466309 s
# total time for one elbow  0.23366308212280273 s
# elbow [3, 4]
# time of building a simplex tree 0.0162811279296875 s
# time of calculating barcodes  0.0007271766662597656 s
# time of finishing calculating rank invariance 0.20441389083862305 s
# total time for one elbow  0.2214221954345703 s
# elbow [3, 5]
# time of building a simplex tree 0.013700246810913086 s
# time of calculating barcodes  0.0009799003601074219 s
# time of finishing calculating rank invariance 0.20621418952941895 s
# total time for one elbow  0.22089433670043945 s
# elbow [3, 6]
# time of building a simplex tree 0.01661992073059082 s
# time of calculating barcodes  0.0010843276977539062 s
# time of finishing calculating rank invariance 0.20108270645141602 s
# total time for one elbow  0.21878695487976074 s
# elbow [3, 7]
# time of building a simplex tree 0.013692140579223633 s
# time of calculating barcodes  0.0006361007690429688 s
# time of finishing calculating rank invariance 0.1990199089050293 s
# total time for one elbow  0.2133481502532959 s
# elbow [3, 8]
# time of building a simplex tree 0.013992071151733398 s
# time of calculating barcodes  0.0008790493011474609 s
# time of finishing calculating rank invariance 0.19458413124084473 s
# total time for one elbow  0.20945525169372559 s
# elbow [3, 9]
# time of building a simplex tree 0.013989925384521484 s
# time of calculating barcodes  0.0005261898040771484 s
# time of finishing calculating rank invariance 0.20239591598510742 s
# total time for one elbow  0.21691203117370605 s
# elbow [3, 10]
# time of building a simplex tree 0.014326095581054688 s
# time of calculating barcodes  0.0006551742553710938 s
# time of finishing calculating rank invariance 0.19620275497436523 s
# total time for one elbow  0.21118402481079102 s
# elbow [3, 11]
# time of building a simplex tree 0.013859033584594727 s
# time of calculating barcodes  0.0007188320159912109 s
# time of finishing calculating rank invariance 0.1987900733947754 s
# total time for one elbow  0.21336793899536133 s
# elbow [4, 0]
# time of building a simplex tree 0.01427602767944336 s
# time of calculating barcodes  0.0006649494171142578 s
# time of finishing calculating rank invariance 0.19233202934265137 s
# total time for one elbow  0.20727300643920898 s
# elbow [4, 1]
# time of building a simplex tree 0.014111042022705078 s
# time of calculating barcodes  0.0007607936859130859 s
# time of finishing calculating rank invariance 0.18473505973815918 s
# total time for one elbow  0.19960689544677734 s
# elbow [4, 2]
# time of building a simplex tree 0.013847827911376953 s
# time of calculating barcodes  0.0006051063537597656 s
# time of finishing calculating rank invariance 0.18848490715026855 s
# total time for one elbow  0.20293784141540527 s
# elbow [4, 3]
# time of building a simplex tree 0.014915943145751953 s
# time of calculating barcodes  0.0005581378936767578 s
# time of finishing calculating rank invariance 0.1976480484008789 s
# total time for one elbow  0.21312212944030762 s
# elbow [4, 4]
# time of building a simplex tree 0.013964176177978516 s
# time of calculating barcodes  0.0007359981536865234 s
# time of finishing calculating rank invariance 0.20275306701660156 s
# total time for one elbow  0.2174532413482666 s
# elbow [4, 5]
# time of building a simplex tree 0.014774799346923828 s
# time of calculating barcodes  0.0006508827209472656 s
# time of finishing calculating rank invariance 0.19696426391601562 s
# total time for one elbow  0.21238994598388672 s
# elbow [4, 6]
# time of building a simplex tree 0.014052152633666992 s
# time of calculating barcodes  0.0006678104400634766 s
# time of finishing calculating rank invariance 0.20831012725830078 s
# total time for one elbow  0.22303009033203125 s
# elbow [4, 7]
# time of building a simplex tree 0.0152130126953125 s
# time of calculating barcodes  0.0006651878356933594 s
# time of finishing calculating rank invariance 0.21936297416687012 s
# total time for one elbow  0.23524117469787598 s
# elbow [4, 8]
# time of building a simplex tree 0.015944242477416992 s
# time of calculating barcodes  0.0006821155548095703 s
# time of finishing calculating rank invariance 0.2303149700164795 s
# total time for one elbow  0.24694132804870605 s
# elbow [4, 9]
# time of building a simplex tree 0.017101764678955078 s
# time of calculating barcodes  0.0007030963897705078 s
# time of finishing calculating rank invariance 0.2106800079345703 s
# total time for one elbow  0.2284848690032959 s
# elbow [4, 10]
# time of building a simplex tree 0.01423192024230957 s
# time of calculating barcodes  0.0006761550903320312 s
# time of finishing calculating rank invariance 0.19310593605041504 s
# total time for one elbow  0.20801401138305664 s
# elbow [4, 11]
# time of building a simplex tree 0.013624906539916992 s
# time of calculating barcodes  0.0008592605590820312 s
# time of finishing calculating rank invariance 0.2029707431793213 s
# total time for one elbow  0.2174549102783203 s
# elbow [5, 0]
# time of building a simplex tree 0.0151519775390625 s
# time of calculating barcodes  0.0011010169982910156 s
# time of finishing calculating rank invariance 0.19822001457214355 s
# total time for one elbow  0.21447300910949707 s
# elbow [5, 1]
# time of building a simplex tree 0.014118194580078125 s
# time of calculating barcodes  0.0011289119720458984 s
# time of finishing calculating rank invariance 0.1798112392425537 s
# total time for one elbow  0.19505834579467773 s
# elbow [5, 2]
# time of building a simplex tree 0.014394998550415039 s
# time of calculating barcodes  0.0006031990051269531 s
# time of finishing calculating rank invariance 0.18611359596252441 s
# total time for one elbow  0.2011117935180664 s
# elbow [5, 3]
# time of building a simplex tree 0.013778924942016602 s
# time of calculating barcodes  0.0006248950958251953 s
# time of finishing calculating rank invariance 0.18050503730773926 s
# total time for one elbow  0.19490885734558105 s
# elbow [5, 4]
# time of building a simplex tree 0.013962984085083008 s
# time of calculating barcodes  0.0006630420684814453 s
# time of finishing calculating rank invariance 0.186126708984375 s
# total time for one elbow  0.20075273513793945 s
# elbow [5, 5]
# time of building a simplex tree 0.015417814254760742 s
# time of calculating barcodes  0.0009589195251464844 s
# time of finishing calculating rank invariance 0.19180798530578613 s
# total time for one elbow  0.20818471908569336 s
# elbow [5, 6]
# time of building a simplex tree 0.014765739440917969 s
# time of calculating barcodes  0.0007412433624267578 s
# time of finishing calculating rank invariance 0.2305898666381836 s
# total time for one elbow  0.24609684944152832 s
# elbow [5, 7]
# time of building a simplex tree 0.013721942901611328 s
# time of calculating barcodes  0.0007109642028808594 s
# time of finishing calculating rank invariance 0.20314812660217285 s
# total time for one elbow  0.21758103370666504 s
# elbow [5, 8]
# time of building a simplex tree 0.013618230819702148 s
# time of calculating barcodes  0.002051830291748047 s
# time of finishing calculating rank invariance 0.24072504043579102 s
# total time for one elbow  0.2563951015472412 s
# elbow [5, 9]
# time of building a simplex tree 0.01424098014831543 s
# time of calculating barcodes  0.0006260871887207031 s
# time of finishing calculating rank invariance 0.193328857421875 s
# total time for one elbow  0.20819592475891113 s
# elbow [5, 10]
# time of building a simplex tree 0.013957977294921875 s
# time of calculating barcodes  0.0007500648498535156 s
# time of finishing calculating rank invariance 0.19758009910583496 s
# total time for one elbow  0.21228814125061035 s
# elbow [5, 11]
# time of building a simplex tree 0.014508962631225586 s
# time of calculating barcodes  0.0009260177612304688 s
# time of finishing calculating rank invariance 0.20167803764343262 s
# total time for one elbow  0.21711301803588867 s
# elbow [6, 0]
# time of building a simplex tree 0.013634920120239258 s
# time of calculating barcodes  0.0008339881896972656 s
# time of finishing calculating rank invariance 0.17324018478393555 s
# total time for one elbow  0.18770909309387207 s
# elbow [6, 1]
# time of building a simplex tree 0.013841867446899414 s
# time of calculating barcodes  0.0006241798400878906 s
# time of finishing calculating rank invariance 0.17477774620056152 s
# total time for one elbow  0.18924379348754883 s
# elbow [6, 2]
# time of building a simplex tree 0.013847827911376953 s
# time of calculating barcodes  0.0006241798400878906 s
# time of finishing calculating rank invariance 0.17669391632080078 s
# total time for one elbow  0.19116592407226562 s
# elbow [6, 3]
# time of building a simplex tree 0.013764142990112305 s
# time of calculating barcodes  0.0005776882171630859 s
# time of finishing calculating rank invariance 0.18921113014221191 s
# total time for one elbow  0.2035529613494873 s
# elbow [6, 4]
# time of building a simplex tree 0.014282941818237305 s
# time of calculating barcodes  0.0010139942169189453 s
# time of finishing calculating rank invariance 0.18570494651794434 s
# total time for one elbow  0.20100188255310059 s
# elbow [6, 5]
# time of building a simplex tree 0.014557123184204102 s
# time of calculating barcodes  0.0008380413055419922 s
# time of finishing calculating rank invariance 0.19393610954284668 s
# total time for one elbow  0.20933127403259277 s
# elbow [6, 6]
# time of building a simplex tree 0.01672506332397461 s
# time of calculating barcodes  0.000720977783203125 s
# time of finishing calculating rank invariance 0.2010490894317627 s
# total time for one elbow  0.21849513053894043 s
# elbow [6, 7]
# time of building a simplex tree 0.016349077224731445 s
# time of calculating barcodes  0.0006968975067138672 s
# time of finishing calculating rank invariance 0.21512913703918457 s
# total time for one elbow  0.23217511177062988 s
# elbow [6, 8]
# time of building a simplex tree 0.01391291618347168 s
# time of calculating barcodes  0.0008311271667480469 s
# time of finishing calculating rank invariance 0.2155590057373047 s
# total time for one elbow  0.23030304908752441 s
# elbow [6, 9]
# time of building a simplex tree 0.017024993896484375 s
# time of calculating barcodes  0.0007309913635253906 s
# time of finishing calculating rank invariance 0.25454187393188477 s
# total time for one elbow  0.27229785919189453 s
# elbow [6, 10]
# time of building a simplex tree 0.022832870483398438 s
# time of calculating barcodes  0.0007579326629638672 s
# time of finishing calculating rank invariance 0.1980741024017334 s
# total time for one elbow  0.2216649055480957 s
# elbow [6, 11]
# time of building a simplex tree 0.014267921447753906 s
# time of calculating barcodes  0.0008270740509033203 s
# time of finishing calculating rank invariance 0.23555302619934082 s
# total time for one elbow  0.25064802169799805 s
# elbow [7, 0]
# time of building a simplex tree 0.014855146408081055 s
# time of calculating barcodes  0.0007905960083007812 s
# time of finishing calculating rank invariance 0.19345927238464355 s
# total time for one elbow  0.2091050148010254 s
# elbow [7, 1]
# time of building a simplex tree 0.014513254165649414 s
# time of calculating barcodes  0.0005538463592529297 s
# time of finishing calculating rank invariance 0.17332696914672852 s
# total time for one elbow  0.18839406967163086 s
# elbow [7, 2]
# time of building a simplex tree 0.013817071914672852 s
# time of calculating barcodes  0.0006051063537597656 s
# time of finishing calculating rank invariance 0.17394185066223145 s
# total time for one elbow  0.18836402893066406 s
# elbow [7, 3]
# time of building a simplex tree 0.013834953308105469 s
# time of calculating barcodes  0.0006008148193359375 s
# time of finishing calculating rank invariance 0.18173503875732422 s
# total time for one elbow  0.19617080688476562 s
# elbow [7, 4]
# time of building a simplex tree 0.015259981155395508 s
# time of calculating barcodes  0.000759124755859375 s
# time of finishing calculating rank invariance 0.17818069458007812 s
# total time for one elbow  0.194199800491333 s
# elbow [7, 5]
# time of building a simplex tree 0.01383209228515625 s
# time of calculating barcodes  0.00061798095703125 s
# time of finishing calculating rank invariance 0.182664155960083 s
# total time for one elbow  0.1971142292022705 s
# elbow [7, 6]
# time of building a simplex tree 0.013890743255615234 s
# time of calculating barcodes  0.0006289482116699219 s
# time of finishing calculating rank invariance 0.18171119689941406 s
# total time for one elbow  0.19623088836669922 s
# elbow [7, 7]
# time of building a simplex tree 0.01395416259765625 s
# time of calculating barcodes  0.0007030963897705078 s
# time of finishing calculating rank invariance 0.19222378730773926 s
# total time for one elbow  0.20688104629516602 s
# elbow [7, 8]
# time of building a simplex tree 0.014143943786621094 s
# time of calculating barcodes  0.0007889270782470703 s
# time of finishing calculating rank invariance 0.19370818138122559 s
# total time for one elbow  0.20864105224609375 s
# elbow [7, 9]
# time of building a simplex tree 0.015591859817504883 s
# time of calculating barcodes  0.0008120536804199219 s
# time of finishing calculating rank invariance 0.19498586654663086 s
# total time for one elbow  0.21138978004455566 s
# elbow [7, 10]
# time of building a simplex tree 0.014025211334228516 s
# time of calculating barcodes  0.0008249282836914062 s
# time of finishing calculating rank invariance 0.19328808784484863 s
# total time for one elbow  0.20813822746276855 s
# elbow [7, 11]
# time of building a simplex tree 0.014003992080688477 s
# time of calculating barcodes  0.0006709098815917969 s
# time of finishing calculating rank invariance 0.1983349323272705 s
# total time for one elbow  0.21300983428955078 s
# elbow [8, 0]
# time of building a simplex tree 0.014039039611816406 s
# time of calculating barcodes  0.0006499290466308594 s
# time of finishing calculating rank invariance 0.17101597785949707 s
# total time for one elbow  0.18570494651794434 s
# elbow [8, 1]
# time of building a simplex tree 0.014184236526489258 s
# time of calculating barcodes  0.0006301403045654297 s
# time of finishing calculating rank invariance 0.1998138427734375 s
# total time for one elbow  0.2146282196044922 s
# elbow [8, 2]
# time of building a simplex tree 0.015362977981567383 s
# time of calculating barcodes  0.0006279945373535156 s
# time of finishing calculating rank invariance 0.1899561882019043 s
# total time for one elbow  0.2059471607208252 s
# elbow [8, 3]
# time of building a simplex tree 0.015165328979492188 s
# time of calculating barcodes  0.0007145404815673828 s
# time of finishing calculating rank invariance 0.18489336967468262 s
# total time for one elbow  0.2007732391357422 s
# elbow [8, 4]
# time of building a simplex tree 0.015064001083374023 s
# time of calculating barcodes  0.0010440349578857422 s
# time of finishing calculating rank invariance 0.19704294204711914 s
# total time for one elbow  0.2131509780883789 s
# elbow [8, 5]
# time of building a simplex tree 0.01442408561706543 s
# time of calculating barcodes  0.0007817745208740234 s
# time of finishing calculating rank invariance 0.1909492015838623 s
# total time for one elbow  0.20615506172180176 s
# elbow [8, 6]
# time of building a simplex tree 0.014807701110839844 s
# time of calculating barcodes  0.0011472702026367188 s
# time of finishing calculating rank invariance 0.2018120288848877 s
# total time for one elbow  0.21776700019836426 s
# elbow [8, 7]
# time of building a simplex tree 0.015233993530273438 s
# time of calculating barcodes  0.0006787776947021484 s
# time of finishing calculating rank invariance 0.19435906410217285 s
# total time for one elbow  0.21027183532714844 s
# elbow [8, 8]
# time of building a simplex tree 0.01657390594482422 s
# time of calculating barcodes  0.0007660388946533203 s
# time of finishing calculating rank invariance 0.2059781551361084 s
# total time for one elbow  0.22331809997558594 s
# elbow [8, 9]
# time of building a simplex tree 0.014484167098999023 s
# time of calculating barcodes  0.0005750656127929688 s
# time of finishing calculating rank invariance 0.20538783073425293 s
# total time for one elbow  0.22044706344604492 s
# elbow [8, 10]
# time of building a simplex tree 0.013726949691772461 s
# time of calculating barcodes  0.0007827281951904297 s
# time of finishing calculating rank invariance 0.19732928276062012 s
# total time for one elbow  0.211838960647583 s
# elbow [8, 11]
# time of building a simplex tree 0.014625072479248047 s
# time of calculating barcodes  0.0006070137023925781 s
# time of finishing calculating rank invariance 0.2102210521697998 s
# total time for one elbow  0.22545313835144043 s
# elbow [9, 0]
# time of building a simplex tree 0.015934228897094727 s
# time of calculating barcodes  0.0009467601776123047 s
# time of finishing calculating rank invariance 0.1773850917816162 s
# total time for one elbow  0.19426608085632324 s
# elbow [9, 1]
# time of building a simplex tree 0.014403104782104492 s
# time of calculating barcodes  0.0012149810791015625 s
# time of finishing calculating rank invariance 0.1712639331817627 s
# total time for one elbow  0.18688201904296875 s
# elbow [9, 2]
# time of building a simplex tree 0.014532089233398438 s
# time of calculating barcodes  0.0005769729614257812 s
# time of finishing calculating rank invariance 0.1880960464477539 s
# total time for one elbow  0.20320510864257812 s
# elbow [9, 3]
# time of building a simplex tree 0.015378952026367188 s
# time of calculating barcodes  0.0008330345153808594 s
# time of finishing calculating rank invariance 0.18060803413391113 s
# total time for one elbow  0.19682002067565918 s
# elbow [9, 4]
# time of building a simplex tree 0.01427602767944336 s
# time of calculating barcodes  0.0007801055908203125 s
# time of finishing calculating rank invariance 0.17778801918029785 s
# total time for one elbow  0.19284415245056152 s
# elbow [9, 5]
# time of building a simplex tree 0.014278173446655273 s
# time of calculating barcodes  0.0006947517395019531 s
# time of finishing calculating rank invariance 0.19339919090270996 s
# total time for one elbow  0.2083721160888672 s
# elbow [9, 6]
# time of building a simplex tree 0.015447854995727539 s
# time of calculating barcodes  0.0006432533264160156 s
# time of finishing calculating rank invariance 0.19680094718933105 s
# total time for one elbow  0.2128920555114746 s
# elbow [9, 7]
# time of building a simplex tree 0.014809131622314453 s
# time of calculating barcodes  0.0007281303405761719 s
# time of finishing calculating rank invariance 0.21643805503845215 s
# total time for one elbow  0.23197531700134277 s
# elbow [9, 8]
# time of building a simplex tree 0.01699209213256836 s
# time of calculating barcodes  0.0013380050659179688 s
# time of finishing calculating rank invariance 0.19750094413757324 s
# total time for one elbow  0.21583104133605957 s
# elbow [9, 9]
# time of building a simplex tree 0.01849198341369629 s
# time of calculating barcodes  0.0010340213775634766 s
# time of finishing calculating rank invariance 0.21221089363098145 s
# total time for one elbow  0.2317368984222412 s
# elbow [9, 10]
# time of building a simplex tree 0.016039133071899414 s
# time of calculating barcodes  0.0009789466857910156 s
# time of finishing calculating rank invariance 0.20692896842956543 s
# total time for one elbow  0.22394704818725586 s
# elbow [9, 11]
# time of building a simplex tree 0.015486001968383789 s
# time of calculating barcodes  0.0007188320159912109 s
# time of finishing calculating rank invariance 0.2150881290435791 s
# total time for one elbow  0.2312929630279541 s
# elbow [10, 0]
# time of building a simplex tree 0.0159909725189209 s
# time of calculating barcodes  0.0008280277252197266 s
# time of finishing calculating rank invariance 0.18437695503234863 s
# total time for one elbow  0.20119595527648926 s
# elbow [10, 1]
# time of building a simplex tree 0.015735864639282227 s
# time of calculating barcodes  0.0006959438323974609 s
# time of finishing calculating rank invariance 0.17193603515625 s
# total time for one elbow  0.1883678436279297 s
# elbow [10, 2]
# time of building a simplex tree 0.013898134231567383 s
# time of calculating barcodes  0.0006139278411865234 s
# time of finishing calculating rank invariance 0.1676468849182129 s
# total time for one elbow  0.1821589469909668 s
# elbow [10, 3]
# time of building a simplex tree 0.013996124267578125 s
# time of calculating barcodes  0.0006198883056640625 s
# time of finishing calculating rank invariance 0.1747572422027588 s
# total time for one elbow  0.18937325477600098 s
# elbow [10, 4]
# time of building a simplex tree 0.01470804214477539 s
# time of calculating barcodes  0.000640869140625 s
# time of finishing calculating rank invariance 0.175490140914917 s
# total time for one elbow  0.19083905220031738 s
# elbow [10, 5]
# time of building a simplex tree 0.014760017395019531 s
# time of calculating barcodes  0.0006279945373535156 s
# time of finishing calculating rank invariance 0.17899107933044434 s
# total time for one elbow  0.19437909126281738 s
# elbow [10, 6]
# time of building a simplex tree 0.014080047607421875 s
# time of calculating barcodes  0.0009059906005859375 s
# time of finishing calculating rank invariance 0.1853199005126953 s
# total time for one elbow  0.20030593872070312 s
# elbow [10, 7]
# time of building a simplex tree 0.020043134689331055 s
# time of calculating barcodes  0.0007340908050537109 s
# time of finishing calculating rank invariance 0.19002890586853027 s
# total time for one elbow  0.21080613136291504 s
# elbow [10, 8]
# time of building a simplex tree 0.014275074005126953 s
# time of calculating barcodes  0.0011429786682128906 s
# time of finishing calculating rank invariance 0.19701004028320312 s
# total time for one elbow  0.21242809295654297 s
# elbow [10, 9]
# time of building a simplex tree 0.014854192733764648 s
# time of calculating barcodes  0.0007789134979248047 s
# time of finishing calculating rank invariance 0.20638179779052734 s
# total time for one elbow  0.2220149040222168 s
# elbow [10, 10]
# time of building a simplex tree 0.017384767532348633 s
# time of calculating barcodes  0.0013551712036132812 s
# time of finishing calculating rank invariance 0.20813822746276855 s
# total time for one elbow  0.22687816619873047 s
# elbow [10, 11]
# time of building a simplex tree 0.016379833221435547 s
# time of calculating barcodes  0.000820159912109375 s
# time of finishing calculating rank invariance 0.2273850440979004 s
# total time for one elbow  0.2445850372314453 s
# elbow [11, 0]
# time of building a simplex tree 0.02408599853515625 s
# time of calculating barcodes  0.0008730888366699219 s
# time of finishing calculating rank invariance 0.16536688804626465 s
# total time for one elbow  0.19032597541809082 s
# elbow [11, 1]
# time of building a simplex tree 0.013920068740844727 s
# time of calculating barcodes  0.0005619525909423828 s
# time of finishing calculating rank invariance 0.17149090766906738 s
# total time for one elbow  0.1859729290008545 s
# elbow [11, 2]
# time of building a simplex tree 0.016693115234375 s
# time of calculating barcodes  0.0006206035614013672 s
# time of finishing calculating rank invariance 0.18634533882141113 s
# total time for one elbow  0.2036590576171875 s
# elbow [11, 3]
# time of building a simplex tree 0.014642000198364258 s
# time of calculating barcodes  0.0007500648498535156 s
# time of finishing calculating rank invariance 0.17119789123535156 s
# total time for one elbow  0.18658995628356934 s
# elbow [11, 4]
# time of building a simplex tree 0.016299962997436523 s
# time of calculating barcodes  0.0006930828094482422 s
# time of finishing calculating rank invariance 0.20193099975585938 s
# total time for one elbow  0.21892404556274414 s
# elbow [11, 5]
# time of building a simplex tree 0.01460409164428711 s
# time of calculating barcodes  0.0006468296051025391 s
# time of finishing calculating rank invariance 0.17615413665771484 s
# total time for one elbow  0.1914050579071045 s
# elbow [11, 6]
# time of building a simplex tree 0.013961076736450195 s
# time of calculating barcodes  0.0005981922149658203 s
# time of finishing calculating rank invariance 0.18365693092346191 s
# total time for one elbow  0.19821619987487793 s
# elbow [11, 7]
# time of building a simplex tree 0.014702081680297852 s
# time of calculating barcodes  0.0010819435119628906 s
# time of finishing calculating rank invariance 0.212507963180542 s
# total time for one elbow  0.22829198837280273 s
# elbow [11, 8]
# time of building a simplex tree 0.014455080032348633 s
# time of calculating barcodes  0.0009958744049072266 s
# time of finishing calculating rank invariance 0.19634294509887695 s
# total time for one elbow  0.2117938995361328 s
# elbow [11, 9]
# time of building a simplex tree 0.015278100967407227 s
# time of calculating barcodes  0.0010499954223632812 s
# time of finishing calculating rank invariance 0.21454405784606934 s
# total time for one elbow  0.23087215423583984 s
# elbow [11, 10]
# time of building a simplex tree 0.016611099243164062 s
# time of calculating barcodes  0.0007390975952148438 s
# time of finishing calculating rank invariance 0.23799967765808105 s
# total time for one elbow  0.25534987449645996 s
# elbow [11, 11]
# time of building a simplex tree 0.01591777801513672 s
# time of calculating barcodes  0.0006608963012695312 s
# time of finishing calculating rank invariance 0.22182512283325195 s
# total time for one elbow  0.2384037971496582 s
# elbow [12, 0]
# time of building a simplex tree 0.022855043411254883 s
# time of calculating barcodes  0.0010018348693847656 s
# time of finishing calculating rank invariance 0.17291998863220215 s
# total time for one elbow  0.1967768669128418 s
# elbow [12, 1]
# time of building a simplex tree 0.014609098434448242 s
# time of calculating barcodes  0.0009958744049072266 s
# time of finishing calculating rank invariance 0.168503999710083 s
# total time for one elbow  0.18410897254943848 s
# elbow [12, 2]
# time of building a simplex tree 0.013835906982421875 s
# time of calculating barcodes  0.0006110668182373047 s
# time of finishing calculating rank invariance 0.18021893501281738 s
# total time for one elbow  0.19466590881347656 s
# elbow [12, 3]
# time of building a simplex tree 0.014869928359985352 s
# time of calculating barcodes  0.0008063316345214844 s
# time of finishing calculating rank invariance 0.1786947250366211 s
# total time for one elbow  0.19437098503112793 s
# elbow [12, 4]
# time of building a simplex tree 0.014087915420532227 s
# time of calculating barcodes  0.0011169910430908203 s
# time of finishing calculating rank invariance 0.16640615463256836 s
# total time for one elbow  0.1816110610961914 s
# elbow [12, 5]
# time of building a simplex tree 0.01404714584350586 s
# time of calculating barcodes  0.0006020069122314453 s
# time of finishing calculating rank invariance 0.17395591735839844 s
# total time for one elbow  0.18860507011413574 s
# elbow [12, 6]
# time of building a simplex tree 0.014617681503295898 s
# time of calculating barcodes  0.0006511211395263672 s
# time of finishing calculating rank invariance 0.1924750804901123 s
# total time for one elbow  0.20774388313293457 s
# elbow [12, 7]
# time of building a simplex tree 0.014733076095581055 s
# time of calculating barcodes  0.0007998943328857422 s
# time of finishing calculating rank invariance 0.1818690299987793 s
# total time for one elbow  0.1974020004272461 s
# elbow [12, 8]
# time of building a simplex tree 0.014342784881591797 s
# time of calculating barcodes  0.0006542205810546875 s
# time of finishing calculating rank invariance 0.17820477485656738 s
# total time for one elbow  0.19320178031921387 s
# elbow [12, 9]
# time of building a simplex tree 0.014245986938476562 s
# time of calculating barcodes  0.0010509490966796875 s
# time of finishing calculating rank invariance 0.19665312767028809 s
# total time for one elbow  0.21195006370544434 s
# elbow [12, 10]
# time of building a simplex tree 0.015496969223022461 s
# time of calculating barcodes  0.0008420944213867188 s
# time of finishing calculating rank invariance 0.19544172286987305 s
# total time for one elbow  0.21178078651428223 s
# elbow [12, 11]
# time of building a simplex tree 0.014394044876098633 s
# time of calculating barcodes  0.0006489753723144531 s
# time of finishing calculating rank invariance 0.1999979019165039 s
# total time for one elbow  0.215040922164917 s
# elbow [13, 0]
# time of building a simplex tree 0.014581918716430664 s
# time of calculating barcodes  0.0007030963897705078 s
# time of finishing calculating rank invariance 0.1734020709991455 s
# total time for one elbow  0.18868708610534668 s
# elbow [13, 1]
# time of building a simplex tree 0.01554417610168457 s
# time of calculating barcodes  0.0005590915679931641 s
# time of finishing calculating rank invariance 0.17122983932495117 s
# total time for one elbow  0.1873331069946289 s
# elbow [13, 2]
# time of building a simplex tree 0.014626741409301758 s
# time of calculating barcodes  0.0007162094116210938 s
# time of finishing calculating rank invariance 0.15959501266479492 s
# total time for one elbow  0.17493796348571777 s
# elbow [13, 3]
# time of building a simplex tree 0.01399683952331543 s
# time of calculating barcodes  0.0006418228149414062 s
# time of finishing calculating rank invariance 0.16059231758117676 s
# total time for one elbow  0.1752309799194336 s
# elbow [13, 4]
# time of building a simplex tree 0.014352083206176758 s
# time of calculating barcodes  0.0008027553558349609 s
# time of finishing calculating rank invariance 0.16363811492919922 s
# total time for one elbow  0.17879295349121094 s
# elbow [13, 5]
# time of building a simplex tree 0.01485896110534668 s
# time of calculating barcodes  0.0006840229034423828 s
# time of finishing calculating rank invariance 0.18668794631958008 s
# total time for one elbow  0.20223093032836914 s
# elbow [13, 6]
# time of building a simplex tree 0.0162351131439209 s
# time of calculating barcodes  0.0008330345153808594 s
# time of finishing calculating rank invariance 0.1772611141204834 s
# total time for one elbow  0.19432926177978516 s
# elbow [13, 7]
# time of building a simplex tree 0.015508890151977539 s
# time of calculating barcodes  0.0008280277252197266 s
# time of finishing calculating rank invariance 0.18816900253295898 s
# total time for one elbow  0.20450592041015625 s
# elbow [13, 8]
# time of building a simplex tree 0.017922163009643555 s
# time of calculating barcodes  0.0009479522705078125 s
# time of finishing calculating rank invariance 0.18953990936279297 s
# total time for one elbow  0.20841002464294434 s
# elbow [13, 9]
# time of building a simplex tree 0.013889789581298828 s
# time of calculating barcodes  0.0009672641754150391 s
# time of finishing calculating rank invariance 0.18799805641174316 s
# total time for one elbow  0.20285511016845703 s
# elbow [13, 10]
# time of building a simplex tree 0.015228271484375 s
# time of calculating barcodes  0.0007789134979248047 s
# time of finishing calculating rank invariance 0.18966197967529297 s
# total time for one elbow  0.20566916465759277 s
# elbow [13, 11]
# time of building a simplex tree 0.015146970748901367 s
# time of calculating barcodes  0.0008788108825683594 s
# time of finishing calculating rank invariance 0.20140504837036133 s
# total time for one elbow  0.21743083000183105 s
# elbow [14, 0]
# time of building a simplex tree 0.013803958892822266 s
# time of calculating barcodes  0.0008780956268310547 s
# time of finishing calculating rank invariance 0.1637568473815918 s
# total time for one elbow  0.17843890190124512 s
# elbow [14, 1]
# time of building a simplex tree 0.015132904052734375 s
# time of calculating barcodes  0.0011110305786132812 s
# time of finishing calculating rank invariance 0.16466879844665527 s
# total time for one elbow  0.18091273307800293 s
# elbow [14, 2]
# time of building a simplex tree 0.015201091766357422 s
# time of calculating barcodes  0.0008420944213867188 s
# time of finishing calculating rank invariance 0.17297792434692383 s
# total time for one elbow  0.18902111053466797 s
# elbow [14, 3]
# time of building a simplex tree 0.015993833541870117 s
# time of calculating barcodes  0.0006461143493652344 s
# time of finishing calculating rank invariance 0.1682298183441162 s
# total time for one elbow  0.18486976623535156 s
# elbow [14, 4]
# time of building a simplex tree 0.015050888061523438 s
# time of calculating barcodes  0.0010900497436523438 s
# time of finishing calculating rank invariance 0.15688300132751465 s
# total time for one elbow  0.17302393913269043 s
# elbow [14, 5]
# time of building a simplex tree 0.01382899284362793 s
# time of calculating barcodes  0.0005958080291748047 s
# time of finishing calculating rank invariance 0.17815613746643066 s
# total time for one elbow  0.1925809383392334 s
# elbow [14, 6]
# time of building a simplex tree 0.016316890716552734 s
# time of calculating barcodes  0.0010290145874023438 s
# time of finishing calculating rank invariance 0.17923498153686523 s
# total time for one elbow  0.1965808868408203 s
# elbow [14, 7]
# time of building a simplex tree 0.01593613624572754 s
# time of calculating barcodes  0.001194000244140625 s
# time of finishing calculating rank invariance 0.17700505256652832 s
# total time for one elbow  0.19413518905639648 s
# elbow [14, 8]
# time of building a simplex tree 0.014568805694580078 s
# time of calculating barcodes  0.0006291866302490234 s
# time of finishing calculating rank invariance 0.17386102676391602 s
# total time for one elbow  0.18905901908874512 s
# elbow [14, 9]
# time of building a simplex tree 0.014002084732055664 s
# time of calculating barcodes  0.0006060600280761719 s
# time of finishing calculating rank invariance 0.1794130802154541 s
# total time for one elbow  0.19402122497558594 s
# elbow [14, 10]
# time of building a simplex tree 0.014520883560180664 s
# time of calculating barcodes  0.0007882118225097656 s
# time of finishing calculating rank invariance 0.20431995391845703 s
# total time for one elbow  0.21962904930114746 s
# elbow [14, 11]
# time of building a simplex tree 0.015949010848999023 s
# time of calculating barcodes  0.0006759166717529297 s
# time of finishing calculating rank invariance 0.23424196243286133 s
# total time for one elbow  0.2508668899536133 s
# elbow [15, 0]
# time of building a simplex tree 0.01569986343383789 s
# time of calculating barcodes  0.0007071495056152344 s
# time of finishing calculating rank invariance 0.16305780410766602 s
# total time for one elbow  0.17946481704711914 s
# elbow [15, 1]
# time of building a simplex tree 0.016180992126464844 s
# time of calculating barcodes  0.0014388561248779297 s
# time of finishing calculating rank invariance 0.16180706024169922 s
# total time for one elbow  0.179426908493042 s
# elbow [15, 2]
# time of building a simplex tree 0.015624046325683594 s
# time of calculating barcodes  0.001074075698852539 s
# time of finishing calculating rank invariance 0.16495800018310547 s
# total time for one elbow  0.1816561222076416 s
# elbow [15, 3]
# time of building a simplex tree 0.01599884033203125 s
# time of calculating barcodes  0.0006630420684814453 s
# time of finishing calculating rank invariance 0.16609501838684082 s
# total time for one elbow  0.18275690078735352 s
# elbow [15, 4]
# time of building a simplex tree 0.0159759521484375 s
# time of calculating barcodes  0.0007219314575195312 s
# time of finishing calculating rank invariance 0.16128206253051758 s
# total time for one elbow  0.1779799461364746 s
# elbow [15, 5]
# time of building a simplex tree 0.015220165252685547 s
# time of calculating barcodes  0.0012149810791015625 s
# time of finishing calculating rank invariance 0.18250107765197754 s
# total time for one elbow  0.19893622398376465 s
# elbow [15, 6]
# time of building a simplex tree 0.015002965927124023 s
# time of calculating barcodes  0.0007290840148925781 s
# time of finishing calculating rank invariance 0.1657578945159912 s
# total time for one elbow  0.1814899444580078 s
# elbow [15, 7]
# time of building a simplex tree 0.014390945434570312 s
# time of calculating barcodes  0.0006363391876220703 s
# time of finishing calculating rank invariance 0.16990184783935547 s
# total time for one elbow  0.18492913246154785 s
# elbow [15, 8]
# time of building a simplex tree 0.013916254043579102 s
# time of calculating barcodes  0.0006029605865478516 s
# time of finishing calculating rank invariance 0.175706148147583 s
# total time for one elbow  0.19022536277770996 s
# elbow [15, 9]
# time of building a simplex tree 0.015523195266723633 s
# time of calculating barcodes  0.0008928775787353516 s
# time of finishing calculating rank invariance 0.1886739730834961 s
# total time for one elbow  0.20509004592895508 s
# elbow [15, 10]
# time of building a simplex tree 0.014748811721801758 s
# time of calculating barcodes  0.0008380413055419922 s
# time of finishing calculating rank invariance 0.1873319149017334 s
# total time for one elbow  0.20291876792907715 s
# elbow [15, 11]
# time of building a simplex tree 0.014727354049682617 s
# time of calculating barcodes  0.0007479190826416016 s
# time of finishing calculating rank invariance 0.20762181282043457 s
# total time for one elbow  0.2230970859527588 s
# elbow [16, 0]
# time of building a simplex tree 0.013844966888427734 s
# time of calculating barcodes  0.0006020069122314453 s
# time of finishing calculating rank invariance 0.14508509635925293 s
# total time for one elbow  0.1595320701599121 s
# elbow [16, 1]
# time of building a simplex tree 0.013998031616210938 s
# time of calculating barcodes  0.0005772113800048828 s
# time of finishing calculating rank invariance 0.15314602851867676 s
# total time for one elbow  0.16772127151489258 s
# elbow [16, 2]
# time of building a simplex tree 0.015909910202026367 s
# time of calculating barcodes  0.0006508827209472656 s
# time of finishing calculating rank invariance 0.16220402717590332 s
# total time for one elbow  0.17876482009887695 s
# elbow [16, 3]
# time of building a simplex tree 0.01661968231201172 s
# time of calculating barcodes  0.0008320808410644531 s
# time of finishing calculating rank invariance 0.1722850799560547 s
# total time for one elbow  0.18973684310913086 s
# elbow [16, 4]
# time of building a simplex tree 0.015506267547607422 s
# time of calculating barcodes  0.0006656646728515625 s
# time of finishing calculating rank invariance 0.16634702682495117 s
# total time for one elbow  0.18251895904541016 s
# elbow [16, 5]
# time of building a simplex tree 0.015351057052612305 s
# time of calculating barcodes  0.0009367465972900391 s
# time of finishing calculating rank invariance 0.16912007331848145 s
# total time for one elbow  0.1854078769683838 s
# elbow [16, 6]
# time of building a simplex tree 0.014185905456542969 s
# time of calculating barcodes  0.0008881092071533203 s
# time of finishing calculating rank invariance 0.17143821716308594 s
# total time for one elbow  0.18651223182678223 s
# elbow [16, 7]
# time of building a simplex tree 0.015245914459228516 s
# time of calculating barcodes  0.0014579296112060547 s
# time of finishing calculating rank invariance 0.17326593399047852 s
# total time for one elbow  0.18996977806091309 s
# elbow [16, 8]
# time of building a simplex tree 0.01638007164001465 s
# time of calculating barcodes  0.0006680488586425781 s
# time of finishing calculating rank invariance 0.18041086196899414 s
# total time for one elbow  0.19745898246765137 s
# elbow [16, 9]
# time of building a simplex tree 0.015624046325683594 s
# time of calculating barcodes  0.0007441043853759766 s
# time of finishing calculating rank invariance 0.1901109218597412 s
# total time for one elbow  0.20647907257080078 s
# elbow [16, 10]
# ...
# time of calculating barcodes  0.0006608963012695312 s
# time of finishing calculating rank invariance 0.058135032653808594 s
# total time for one elbow  0.08190011978149414 s
# elbow [176, 6]
# time of building a simplex tree 0.02193307876586914 s
# time of calculating barcodes  0.0007398128509521484 s
# time of finishing calculating rank invariance 0.0634610652923584 s
# total time for one elbow  0.08613395690917969 s
# elbow [176, 7]
# time of building a simplex tree 0.022858142852783203 s
# time of calculating barcodes  0.0008711814880371094 s
# time of finishing calculating rank invariance 0.06792378425598145 s
# total time for one elbow  0.09165310859680176 s
# elbow [176, 8]
# time of building a simplex tree 0.02187800407409668 s
# time of calculating barcodes  0.000637054443359375 s
# time of finishing calculating rank invariance 0.0683598518371582 s
# total time for one elbow  0.09087491035461426 s
# elbow [176, 9]
# time of building a simplex tree 0.022994041442871094 s
# time of calculating barcodes  0.0007538795471191406 s
# time of finishing calculating rank invariance 0.0765531063079834 s
# total time for one elbow  0.10030102729797363 s
# elbow [176, 10]
# time of building a simplex tree 0.02195572853088379 s
# time of calculating barcodes  0.0006389617919921875 s
# time of finishing calculating rank invariance 0.07753801345825195 s
# total time for one elbow  0.10013270378112793 s
# elbow [176, 11]
# time of building a simplex tree 0.0140838623046875 s
# time of calculating barcodes  0.0009200572967529297 s
# time of finishing calculating rank invariance 0.19609904289245605 s
# total time for one elbow  0.21110296249389648 s
# elbow [177, 0]
# time of building a simplex tree 0.02358102798461914 s
# time of calculating barcodes  0.0006561279296875 s
# time of finishing calculating rank invariance 0.04236793518066406 s
# total time for one elbow  0.0666050910949707 s
# elbow [177, 1]
# time of building a simplex tree 0.023089885711669922 s
# time of calculating barcodes  0.0006151199340820312 s
# time of finishing calculating rank invariance 0.044010162353515625 s
# total time for one elbow  0.06771516799926758 s
# elbow [177, 2]
# time of building a simplex tree 0.023082971572875977 s
# time of calculating barcodes  0.0006611347198486328 s
# time of finishing calculating rank invariance 0.04872584342956543 s
# total time for one elbow  0.07246994972229004 s
# elbow [177, 3]
# time of building a simplex tree 0.022963762283325195 s
# time of calculating barcodes  0.0006930828094482422 s
# time of finishing calculating rank invariance 0.052368879318237305 s
# total time for one elbow  0.07602572441101074 s
# elbow [177, 4]
# time of building a simplex tree 0.02289104461669922 s
# time of calculating barcodes  0.0006918907165527344 s
# time of finishing calculating rank invariance 0.05366706848144531 s
# total time for one elbow  0.07725000381469727 s
# elbow [177, 5]
# time of building a simplex tree 0.023307085037231445 s
# time of calculating barcodes  0.0007150173187255859 s
# time of finishing calculating rank invariance 0.05754804611206055 s
# total time for one elbow  0.08157014846801758 s
# elbow [177, 6]
# time of building a simplex tree 0.024405956268310547 s
# time of calculating barcodes  0.0006418228149414062 s
# time of finishing calculating rank invariance 0.05970621109008789 s
# total time for one elbow  0.08475399017333984 s
# elbow [177, 7]
# time of building a simplex tree 0.023936033248901367 s
# time of calculating barcodes  0.0010690689086914062 s
# time of finishing calculating rank invariance 0.06585979461669922 s
# total time for one elbow  0.09086489677429199 s
# elbow [177, 8]
# time of building a simplex tree 0.022070884704589844 s
# time of calculating barcodes  0.000637054443359375 s
# time of finishing calculating rank invariance 0.0677480697631836 s
# total time for one elbow  0.09045600891113281 s
# elbow [177, 9]
# time of building a simplex tree 0.022317886352539062 s
# time of calculating barcodes  0.0006279945373535156 s
# time of finishing calculating rank invariance 0.07132101058959961 s
# total time for one elbow  0.09426689147949219 s
# elbow [177, 10]
# time of building a simplex tree 0.021622896194458008 s
# time of calculating barcodes  0.0006051063537597656 s
# time of finishing calculating rank invariance 0.07727193832397461 s
# total time for one elbow  0.09949994087219238 s
# elbow [177, 11]
# time of building a simplex tree 0.014024019241333008 s
# time of calculating barcodes  0.0007100105285644531 s
# time of finishing calculating rank invariance 0.19962096214294434 s
# total time for one elbow  0.2143549919128418 s
# elbow [178, 0]
# time of building a simplex tree 0.02337503433227539 s
# time of calculating barcodes  0.0007228851318359375 s
# time of finishing calculating rank invariance 0.04229927062988281 s
# total time for one elbow  0.06639719009399414 s
# elbow [178, 1]
# time of building a simplex tree 0.02330613136291504 s
# time of calculating barcodes  0.0006647109985351562 s
# time of finishing calculating rank invariance 0.04388713836669922 s
# total time for one elbow  0.06785798072814941 s
# elbow [178, 2]
# time of building a simplex tree 0.023099899291992188 s
# time of calculating barcodes  0.0006000995635986328 s
# time of finishing calculating rank invariance 0.04891180992126465 s
# total time for one elbow  0.07261180877685547 s
# elbow [178, 3]
# time of building a simplex tree 0.023135900497436523 s
# time of calculating barcodes  0.0007419586181640625 s
# time of finishing calculating rank invariance 0.05275321006774902 s
# total time for one elbow  0.07663106918334961 s
# elbow [178, 4]
# time of building a simplex tree 0.023034095764160156 s
# time of calculating barcodes  0.0007507801055908203 s
# time of finishing calculating rank invariance 0.05358314514160156 s
# total time for one elbow  0.07736802101135254 s
# elbow [178, 5]
# time of building a simplex tree 0.022489070892333984 s
# time of calculating barcodes  0.0005941390991210938 s
# time of finishing calculating rank invariance 0.05648994445800781 s
# total time for one elbow  0.07957315444946289 s
# elbow [178, 6]
# time of building a simplex tree 0.022108078002929688 s
# time of calculating barcodes  0.0006620883941650391 s
# time of finishing calculating rank invariance 0.061438798904418945 s
# total time for one elbow  0.08420896530151367 s
# elbow [178, 7]
# time of building a simplex tree 0.022466182708740234 s
# time of calculating barcodes  0.0007390975952148438 s
# time of finishing calculating rank invariance 0.06438779830932617 s
# total time for one elbow  0.08759307861328125 s
# elbow [178, 8]
# time of building a simplex tree 0.022056102752685547 s
# time of calculating barcodes  0.0005269050598144531 s
# time of finishing calculating rank invariance 0.06761789321899414 s
# total time for one elbow  0.09020090103149414 s
# elbow [178, 9]
# time of building a simplex tree 0.023489952087402344 s
# time of calculating barcodes  0.0010330677032470703 s
# time of finishing calculating rank invariance 0.07154202461242676 s
# total time for one elbow  0.09606504440307617 s
# elbow [178, 10]
# time of building a simplex tree 0.02158522605895996 s
# time of calculating barcodes  0.0005979537963867188 s
# time of finishing calculating rank invariance 0.0764608383178711 s
# total time for one elbow  0.09864401817321777 s
# elbow [178, 11]
# time of building a simplex tree 0.013839960098266602 s
# time of calculating barcodes  0.0006000995635986328 s
# time of finishing calculating rank invariance 0.1983349323272705 s
# total time for one elbow  0.21277499198913574 s
# elbow [179, 0]
# time of building a simplex tree 0.023286104202270508 s
# time of calculating barcodes  0.0005960464477539062 s
# time of finishing calculating rank invariance 0.04005599021911621 s
# total time for one elbow  0.06393814086914062 s
# elbow [179, 1]
# time of building a simplex tree 0.023205041885375977 s
# time of calculating barcodes  0.0005691051483154297 s
# time of finishing calculating rank invariance 0.04336285591125488 s
# total time for one elbow  0.06713700294494629 s
# elbow [179, 2]
# time of building a simplex tree 0.023322105407714844 s
# time of calculating barcodes  0.0006399154663085938 s
# time of finishing calculating rank invariance 0.048454999923706055 s
# total time for one elbow  0.07241702079772949 s
# elbow [179, 3]
# time of building a simplex tree 0.023328065872192383 s
# time of calculating barcodes  0.0006878376007080078 s
# time of finishing calculating rank invariance 0.05317497253417969 s
# total time for one elbow  0.07719087600708008 s
# elbow [179, 4]
# time of building a simplex tree 0.023237943649291992 s
# time of calculating barcodes  0.0006279945373535156 s
# time of finishing calculating rank invariance 0.053681135177612305 s
# total time for one elbow  0.07754707336425781 s
# elbow [179, 5]
# time of building a simplex tree 0.02284693717956543 s
# time of calculating barcodes  0.0005970001220703125 s
# time of finishing calculating rank invariance 0.057498931884765625 s
# total time for one elbow  0.08094286918640137 s
# elbow [179, 6]
# time of building a simplex tree 0.023946046829223633 s
# time of calculating barcodes  0.0010118484497070312 s
# time of finishing calculating rank invariance 0.06088614463806152 s
# total time for one elbow  0.08584403991699219 s
# elbow [179, 7]
# time of building a simplex tree 0.022605180740356445 s
# time of calculating barcodes  0.0007989406585693359 s
# time of finishing calculating rank invariance 0.06473898887634277 s
# total time for one elbow  0.08814311027526855 s
# elbow [179, 8]
# time of building a simplex tree 0.022015094757080078 s
# time of calculating barcodes  0.0005970001220703125 s
# time of finishing calculating rank invariance 0.06900405883789062 s
# total time for one elbow  0.09161615371704102 s
# elbow [179, 9]
# time of building a simplex tree 0.022639989852905273 s
# time of calculating barcodes  0.0006477832794189453 s
# time of finishing calculating rank invariance 0.07087421417236328 s
# total time for one elbow  0.0941619873046875 s
# elbow [179, 10]
# time of building a simplex tree 0.02173304557800293 s
# time of calculating barcodes  0.0006029605865478516 s
# time of finishing calculating rank invariance 0.07686710357666016 s
# total time for one elbow  0.09920310974121094 s
# elbow [179, 11]
# time of building a simplex tree 0.014012336730957031 s
# time of calculating barcodes  0.0007369518280029297 s
# time of finishing calculating rank invariance 0.19625282287597656 s
# total time for one elbow  0.21100211143493652 s
# elbow [180, 0]
# time of building a simplex tree 0.023593902587890625 s
# time of calculating barcodes  0.0007162094116210938 s
# time of finishing calculating rank invariance 0.042453765869140625 s
# total time for one elbow  0.06676387786865234 s
# elbow [180, 1]
# time of building a simplex tree 0.0235748291015625 s
# time of calculating barcodes  0.0006542205810546875 s
# time of finishing calculating rank invariance 0.0437769889831543 s
# total time for one elbow  0.06800603866577148 s
# elbow [180, 2]
# time of building a simplex tree 0.023455142974853516 s
# time of calculating barcodes  0.0006730556488037109 s
# time of finishing calculating rank invariance 0.049170732498168945 s
# total time for one elbow  0.07329893112182617 s
# elbow [180, 3]
# time of building a simplex tree 0.023478031158447266 s
# time of calculating barcodes  0.0006861686706542969 s
# time of finishing calculating rank invariance 0.053021907806396484 s
# total time for one elbow  0.07718610763549805 s
# elbow [180, 4]
# time of building a simplex tree 0.022983074188232422 s
# time of calculating barcodes  0.0005829334259033203 s
# time of finishing calculating rank invariance 0.05341911315917969 s
# total time for one elbow  0.07698512077331543 s
# elbow [180, 5]
# time of building a simplex tree 0.02314591407775879 s
# time of calculating barcodes  0.0007522106170654297 s
# time of finishing calculating rank invariance 0.05693173408508301 s
# total time for one elbow  0.08082985877990723 s
# elbow [180, 6]
# time of building a simplex tree 0.02445220947265625 s
# time of calculating barcodes  0.0008027553558349609 s
# time of finishing calculating rank invariance 0.05976414680480957 s
# total time for one elbow  0.08501911163330078 s
# elbow [180, 7]
# time of building a simplex tree 0.02289891242980957 s
# time of calculating barcodes  0.0006840229034423828 s
# time of finishing calculating rank invariance 0.06435680389404297 s
# total time for one elbow  0.08793973922729492 s
# elbow [180, 8]
# time of building a simplex tree 0.02229475975036621 s
# time of calculating barcodes  0.0006222724914550781 s
# time of finishing calculating rank invariance 0.06862878799438477 s
# total time for one elbow  0.09154582023620605 s
# elbow [180, 9]
# time of building a simplex tree 0.023048877716064453 s
# time of calculating barcodes  0.0006878376007080078 s
# time of finishing calculating rank invariance 0.07025504112243652 s
# total time for one elbow  0.09399175643920898 s
# elbow [180, 10]
# time of building a simplex tree 0.02387523651123047 s
# time of calculating barcodes  0.0005939006805419922 s
# time of finishing calculating rank invariance 0.07671117782592773 s
# total time for one elbow  0.1011803150177002 s
# elbow [180, 11]
# time of building a simplex tree 0.014117002487182617 s
# time of calculating barcodes  0.0007300376892089844 s
# time of finishing calculating rank invariance 0.1963820457458496 s
# total time for one elbow  0.2112290859222412 s
# elbow [181, 0]
# time of building a simplex tree 0.024873971939086914 s
# time of calculating barcodes  0.0006420612335205078 s
# time of finishing calculating rank invariance 0.04263615608215332 s
# total time for one elbow  0.06815218925476074 s
# elbow [181, 1]
# time of building a simplex tree 0.02379012107849121 s
# time of calculating barcodes  0.0006017684936523438 s
# time of finishing calculating rank invariance 0.04367780685424805 s
# total time for one elbow  0.0680696964263916 s
# elbow [181, 2]
# time of building a simplex tree 0.023543119430541992 s
# time of calculating barcodes  0.0006120204925537109 s
# time of finishing calculating rank invariance 0.04898190498352051 s
# total time for one elbow  0.07313704490661621 s
# elbow [181, 3]
# time of building a simplex tree 0.02369093894958496 s
# time of calculating barcodes  0.0006840229034423828 s
# time of finishing calculating rank invariance 0.0527338981628418 s
# total time for one elbow  0.07710886001586914 s
# elbow [181, 4]
# time of building a simplex tree 0.023551225662231445 s
# time of calculating barcodes  0.0009217262268066406 s
# time of finishing calculating rank invariance 0.05389118194580078 s
# total time for one elbow  0.07836413383483887 s
# elbow [181, 5]
# time of building a simplex tree 0.022996902465820312 s
# time of calculating barcodes  0.0006070137023925781 s
# time of finishing calculating rank invariance 0.05685687065124512 s
# total time for one elbow  0.08046078681945801 s
# elbow [181, 6]
# time of building a simplex tree 0.02428603172302246 s
# time of calculating barcodes  0.0009191036224365234 s
# time of finishing calculating rank invariance 0.06024909019470215 s
# total time for one elbow  0.08545422554016113 s
# elbow [181, 7]
# time of building a simplex tree 0.02286696434020996 s
# time of calculating barcodes  0.0006778240203857422 s
# time of finishing calculating rank invariance 0.06471490859985352 s
# total time for one elbow  0.08825969696044922 s
# elbow [181, 8]
# time of building a simplex tree 0.022372961044311523 s
# time of calculating barcodes  0.0006120204925537109 s
# time of finishing calculating rank invariance 0.06745123863220215 s
# total time for one elbow  0.09043622016906738 s
# elbow [181, 9]
# time of building a simplex tree 0.023240089416503906 s
# time of calculating barcodes  0.0007870197296142578 s
# time of finishing calculating rank invariance 0.07238602638244629 s
# total time for one elbow  0.09641313552856445 s
# elbow [181, 10]
# time of building a simplex tree 0.022767066955566406 s
# time of calculating barcodes  0.0006480216979980469 s
# time of finishing calculating rank invariance 0.07715988159179688 s
# total time for one elbow  0.10057497024536133 s
# elbow [181, 11]
# time of building a simplex tree 0.014172792434692383 s
# time of calculating barcodes  0.0007159709930419922 s
# time of finishing calculating rank invariance 0.19615411758422852 s
# total time for one elbow  0.2110428810119629 s

# %%
#Now it's rank0_invariance
np.save("./result/rank"+str(rank_dim)+"_invariance_for_"+file_name,rank_inv)

#for i in range(x_range+1):
#    for j in range(y_range+1):
#        for k in range(i,x_range+1):
#            for l in range(j,y_range+1):
#                print("rank(({0},{1}),({2},{3}))={4}".format(i,j,k,l,int(rank_inv[i,j,k,l])))

# %% [markdown]
# ## compute multiplicity

# %%
#
#m((i,j),(k,l))
def multp(rank, i,j,k,l):
    if(i<0 or j<0 or k>rank.shape[1] or l>rank.shape[0]):   
        return 0
    
    res = rank[i,j,k,l]
    #print("res=",res)
    if(k+1<rank.shape[0]):
        #print("rank[i,j,k+1,l]=",rank[i,j,k+1,l])
        res -= rank[i,j,k+1,l]
        #print("res=",res)
    if(l+1<rank.shape[1]):
        #print("rank[i,j,k,l+1]=",rank[i,j,k,l+1])
        res -= rank[i,j,k,l+1]
        #print("res=",res)
    if(k+1<rank.shape[0] and l+1<rank.shape[1]):
        #print("rank[i,j,k+1,l+1]=",rank[i,j,k+1,l+1])
        res += rank[i,j,k+1,l+1]
        #print("res=",res)
    #print("=================multp(({0},{1}),({2},{3}))={4}===================".format(i,j,k,l,res))
    return res
    

def compute_R_S_incl_excl(rank):
    multiplicity = np.zeros_like(rank)
    for i in range(rank.shape[0]):
        for j in range(rank.shape[1]):
            for k in range(i,rank.shape[0]):
                for l in range(j,rank.shape[1]):
                    m = multp(rank,i,j,k,l)-multp(rank,i-1,j,k,l)-multp(rank,i,j-1,k,l)+multp(rank,i-1,j-1,k,l)
                    if(m!=0):
                        multiplicity[i,j,k,l] = m
    return multiplicity

# %%
rank_inv.shape
# Out:
# (182, 12, 182, 12)

# %%
m_start_time = time.time()
m = compute_R_S_incl_excl(rank_inv)

m_end_time = time.time()
print("time of calculating multiplicity:",m_end_time-m_start_time,"s")

np.save("./result/rank"+str(rank_dim)+"_multiplicity_for_"+file_name,m)
# Out:
# time of calculating multiplicity: 0.0 s

# %% [markdown]
# ### Draw grid for multiplicity

# %%
data = np.ones((x_range,y_range)) * np.nan

fig, ax = plt.subplots(1, 1, figsize=(10,10),tight_layout=True)
for x in range(x_range+1):
    ax.axvline(x, lw=1, color='k', zorder=5) # Horizontal 
for y in range(y_range+1):
    ax.axhline(y, lw=1, color='k', zorder=5) # Ordinate
print(m.shape)

for i in range(m.shape[0]):
    for j in range(m.shape[1]):
        for k in range(i,m.shape[0]):
            for l in range(j,m.shape[1]):
                if(m[i,j,k,l]):
                    print("m(({0},{1}),({2},{3}))={4}".format(i,j,k,l,int(m[i,j,k,l])))
                if(m[i,j,k,l]>0):
                    if(i==k and j==l):
                        ax.plot([i, k], [j, l],'bo', linestyle="-")
                    elif(i==k):
                        ax.plot([i+0.08, k+0.08], [j, l],'bv', linestyle="-")
                    elif(j==l):
                        ax.plot([i, k], [j+0.08, l+0.08],'bv',linestyle="-")
                    else:  
                        ax.plot([i, k], [j, l],'bv', linestyle="-")
                if(m[i,j,k,l]<0):
                    if(i==k and j==l):
                        ax.plot([i, k], [j, l],'ro', linestyle="-")
                    elif(i==k):
                        ax.plot([i-0.08, k-0.08], [j, l],'rv', linestyle="-")
                    elif(j==l):
                        ax.plot([i, k], [j-0.08, l-0.08],'rv', linestyle="-")
                    else:  
                        ax.plot([i, k], [j, l], 'rv', linestyle="-")

ax.imshow(data, interpolation='none', extent=[-1,x_range+1, -1, y_range+1], zorder=0)

#ax.axis('off')
# Out:
# (182, 12, 182, 12)
# m((0,1),(7,3))=-1
# m((0,1),(7,11))=1
# m((0,2),(0,11))=1
# m((0,4),(3,11))=1
# m((0,5),(1,11))=1
# m((0,6),(2,11))=1
# m((0,7),(4,11))=1
# m((0,8),(5,11))=1
# m((0,9),(6,11))=1
# m((0,10),(8,11))=1
# m((0,11),(9,11))=1
# m((0,11),(10,11))=1
# m((0,11),(11,11))=1
# m((0,11),(12,11))=1
