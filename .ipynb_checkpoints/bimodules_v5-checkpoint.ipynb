# %%
from IPython.display import Image
from os import chdir
import numpy as np
import gudhi as gd
import matplotlib.pyplot as plt
import matplotlib

# %%
# read the file
file_name = "function_rips_with_threshold_1000_1"
#file_name="fig3-2"

rank_dim = 0

simplices = []
vertice_id = 0
i = 0

x_values = []
y_values = []

for line in open("../cgta_paper_2021/function_rips/"+file_name+".scc"):
#for line in open("./data/"+file_name+".txt"):
    if(line[0]!='#'):
        
        if(i<=1):
            i=i+1
            continue
            
        elif(i==2):
            rank_num=[] # sizes of generating sets
            for j in line.split():
                rank_num.append(int(j))
            i=i+1
            rank_num=rank_num[:-1]
            print("rank_num=",rank_num)
        else:
            block = line.split(';')
            grid = block[0].split()
            grid_x = float(grid[0])
            grid_y = float(grid[1])
            #grid_x = int(float(grid[0])*20)
            #grid_y = int(float(grid[1])*20)
            x_values.append(grid_x)
            y_values.append(grid_y)
            
            
            if len(block)>1:
                face = block[1].split()
                for j in range(len(face)):
                    face[j] = int(face[j])
                simplices.append([grid_x,grid_y,face])
                
            else:
                simplices.append([grid_x,grid_y,[vertice_id]])
                vertice_id += 1
            i=i+1   




simplex_tree = []
start_id=0
for i in range(len(rank_num)-1,-1,-1):
    simplices_i=[]
    for j in range(len(simplices)-start_id-rank_num[i],len(simplices)-start_id):
        simplices_i.append(simplices[j])
    start_id += rank_num[i]
    simplex_tree.append(simplices_i)
    


#transform face number to vertex number
for i in range(1,len(simplex_tree)):
    for j in range(len(simplex_tree[i])):
        simplex = simplex_tree[i][j]
        face = simplex[2]
        vertices=[]
        for face_id in face:
            vert = simplex_tree[i-1][face_id][2]
            for vert_id in vert:
                if vert_id not in vertices:
                    vertices.append(vert_id)
        simplex_tree[i][j][2]=vertices



## To verify the data structur
## simplices contain all the information we need
#print("the simplex tree:")
#for i in range(len(simplex_tree)):
#    for simplex in simplex_tree[i]:
#        print(simplex)
# Out:
# rank_num= [447, 347, 181, 50]

# %%
x_values_ordered = sorted(list({}.fromkeys(x_values).keys()))
y_values_ordered = sorted(list({}.fromkeys(y_values).keys()))


simplex_tree_integer=simplex_tree

for i in range(len(simplex_tree_integer)):
    for j in range(len(simplex_tree_integer[i])):
        simplex_tree_integer[i][j][0]=x_values_ordered.index(simplex_tree_integer[i][j][0])
        simplex_tree_integer[i][j][1]=y_values_ordered.index(simplex_tree_integer[i][j][1])

# %%
x_range=len(x_values_ordered)-1
y_range=len(y_values_ordered)-1

end_point = [x_range,y_range]
print("end_point ",end_point)
# Out:
# end_point  [181, 11]

# %% [markdown]
# ## Compute rank invariant

# %%
def create_stair(elbow, end_point):
    # stair a path passing through the elbow.
    stair = []
    
    if(elbow[0]==0 or elbow[1]==end_point[1]):
        for i in range(end_point[1]+1):
            stair.append([0,i])
        for j in range(1,end_point[0]+1):
            stair.append([j,i])
    else:
        for i in range(elbow[1]+1):
            stair.append([0,i])   # i=0
        for j in range(elbow[0]):
            stair.append([j+1,i]) # j=0
        for k in range(i+1, end_point[1]+1):
            stair.append([j+1,k]) # k=2,3
        for l in range(j+2, end_point[0]+1):
            stair.append([l,k])
    return stair

def compute_rk(i,j,k,l,barcodes,rank_dim):
# This function computes the value rank(s,t) where s=(i,j) and t = (k,l)
    if(i>k or j>l):
        return 0
    
    s_1 = i + j
    t_1 = k + l
    rank0_inv = 0
    rank1_inv = 0

    for barcode in barcodes:
        if(barcode[0]==0):
            if(barcode[1][0]<=s_1 and barcode[1][1]>t_1):
                rank0_inv = rank0_inv + 1
        elif(barcode[0]==1):
            if(barcode[1][0]<=s_1 and barcode[1][1]>t_1):
                rank1_inv = rank1_inv + 1
    if(rank_dim==0):
        return rank0_inv
    elif(rank_dim==1):
        return rank1_inv

# %%
import time
#grid is from (0,0)
#vertex index is from 1
rank_inv = np.array(np.zeros((x_range+1,y_range+1,x_range+1,y_range+1)))

st = gd.SimplexTree()
#result_rank_fn="./result/rank1_invariance_for_"+file_name+".txt"
#f_rank = f.open(result_rank_fn,"w")



#Scan all the elbows
for i in range(x_range+1):
    for j in range(y_range+1):
        elbow = [i,j]
        print("elbow",elbow)
        start_time=time.time()
        #print("time: start building a simplex tree",time.time())
        stair = create_stair(elbow, end_point)
        #print("stair",stair)

        # Build the simplex tree
        
        for ii in range(len(simplex_tree_integer)):
            for jj in range(len(simplex_tree_integer[ii])):
                simplex = simplex_tree_integer[ii][jj]
                for grid_id in stair:
                    if simplex[0]<=grid_id[0] and simplex[1]<=grid_id[1]:
                        filtration_value = grid_id[0]+grid_id[1] #TODO
                        #print("time enter insert/assign ", time.asctime( time.localtime(time.time())))
                        if((st.insert(simplex[2], filtration = filtration_value))==False): #TODO:optimize with C++, we don't have the funciton for Python
                            #print("time finish insert",time.asctime( time.localtime(time.time())))
                            st.assign_filtration(simplex[2], filtration = filtration_value)
                        break
                        
        st_time=time.time()                
        print("seconds of building a simplex tree",st_time-start_time)
        
        #st_gen = st.get_filtration() 
        #for splx in st_gen :
        #    print(splx)
        
        barcodes = st.persistence()
        #print("barcodes,",barcodes)
        bc_time =time.time()
        print("time of calculating barcodes ",bc_time-st_time)
        
        for start_id in range(len(stair)):
            for end_id in range(start_id,len(stair)):
                grid_start = stair[start_id]
                grid_end = stair[end_id]
                [ri,rj,rk,rl]=[grid_start[0],grid_start[1],grid_end[0],grid_end[1]]
                #print("[ri,rj,rk,rl]=",[ri,rj,rk,rl])
                rank_inv[ri,rj,rk,rl]=compute_rk(ri,rj,rk,rl,barcodes,rank_dim)
        ri_time = time.time()
        print("time finish calculating rank invariance",ri_time-bc_time)
        print("total time for one elbow ",ri_time-start_time)
# Out:
# elbow [0, 0]
# seconds of building a simplex tree 0.014935731887817383
# time of calculating barcodes  0.0007159709930419922
# time finish calculating rank invariance 0.2092883586883545
# total time for one elbow  0.22494006156921387
# elbow [0, 1]
# seconds of building a simplex tree 0.013762950897216797
# time of calculating barcodes  0.0006029605865478516
# time finish calculating rank invariance 0.20363688468933105
# total time for one elbow  0.2180027961730957
# elbow [0, 2]
# seconds of building a simplex tree 0.015341043472290039
# time of calculating barcodes  0.0006158351898193359
# time finish calculating rank invariance 0.22001409530639648
# total time for one elbow  0.23597097396850586
# elbow [0, 3]
# seconds of building a simplex tree 0.01624584197998047
# time of calculating barcodes  0.0008652210235595703
# time finish calculating rank invariance 0.20132088661193848
# total time for one elbow  0.21843194961547852
# elbow [0, 4]
# seconds of building a simplex tree 0.01381683349609375
# time of calculating barcodes  0.0006883144378662109
# time finish calculating rank invariance 0.21014189720153809
# total time for one elbow  0.22464704513549805
# elbow [0, 5]
# seconds of building a simplex tree 0.014895915985107422
# time of calculating barcodes  0.0006251335144042969
# time finish calculating rank invariance 0.20866680145263672
# total time for one elbow  0.22418785095214844
# elbow [0, 6]
# seconds of building a simplex tree 0.013987064361572266
# time of calculating barcodes  0.0007159709930419922
# time finish calculating rank invariance 0.20693302154541016
# total time for one elbow  0.22163605690002441
# elbow [0, 7]
# seconds of building a simplex tree 0.013679981231689453
# time of calculating barcodes  0.0008280277252197266
# time finish calculating rank invariance 0.20621919631958008
# total time for one elbow  0.22072720527648926
# elbow [0, 8]
# seconds of building a simplex tree 0.01439809799194336
# time of calculating barcodes  0.0006778240203857422
# time finish calculating rank invariance 0.20459222793579102
# total time for one elbow  0.21966814994812012
# elbow [0, 9]
# seconds of building a simplex tree 0.014262676239013672
# time of calculating barcodes  0.0010311603546142578
# time finish calculating rank invariance 0.2368028163909912
# total time for one elbow  0.25209665298461914
# elbow [0, 10]
# seconds of building a simplex tree 0.01708388328552246
# time of calculating barcodes  0.0009930133819580078
# time finish calculating rank invariance 0.2060563564300537
# total time for one elbow  0.22413325309753418
# elbow [0, 11]
# seconds of building a simplex tree 0.013796091079711914
# time of calculating barcodes  0.0007088184356689453
# time finish calculating rank invariance 0.20516014099121094
# total time for one elbow  0.2196650505065918
# elbow [1, 0]
# seconds of building a simplex tree 0.01373600959777832
# time of calculating barcodes  0.0008397102355957031
# time finish calculating rank invariance 0.2026224136352539
# total time for one elbow  0.21719813346862793
# elbow [1, 1]
# seconds of building a simplex tree 0.013896942138671875
# time of calculating barcodes  0.0006771087646484375
# time finish calculating rank invariance 0.2053229808807373
# total time for one elbow  0.21989703178405762
# elbow [1, 2]
# seconds of building a simplex tree 0.013737916946411133
# time of calculating barcodes  0.0007429122924804688
# time finish calculating rank invariance 0.21955204010009766
# total time for one elbow  0.23403286933898926
# elbow [1, 3]
# seconds of building a simplex tree 0.014161109924316406
# time of calculating barcodes  0.000942230224609375
# time finish calculating rank invariance 0.20236968994140625
# total time for one elbow  0.21747303009033203
# elbow [1, 4]
# seconds of building a simplex tree 0.013659238815307617
# time of calculating barcodes  0.0008530616760253906
# time finish calculating rank invariance 0.2021198272705078
# total time for one elbow  0.21663212776184082
# elbow [1, 5]
# seconds of building a simplex tree 0.013650178909301758
# time of calculating barcodes  0.0006489753723144531
# time finish calculating rank invariance 0.2014310359954834
# total time for one elbow  0.2157301902770996
# elbow [1, 6]
# seconds of building a simplex tree 0.013672113418579102
# time of calculating barcodes  0.0006439685821533203
# time finish calculating rank invariance 0.20631885528564453
# total time for one elbow  0.22063493728637695
# elbow [1, 7]
# seconds of building a simplex tree 0.013731718063354492
# time of calculating barcodes  0.0008299350738525391
# time finish calculating rank invariance 0.20230817794799805
# total time for one elbow  0.21686983108520508
# elbow [1, 8]
# seconds of building a simplex tree 0.013586044311523438
# time of calculating barcodes  0.0008549690246582031
# time finish calculating rank invariance 0.20128893852233887
# total time for one elbow  0.2157299518585205
# elbow [1, 9]
# seconds of building a simplex tree 0.01371312141418457
# time of calculating barcodes  0.0006511211395263672
# time finish calculating rank invariance 0.20217275619506836
# total time for one elbow  0.2165369987487793
# elbow [1, 10]
# seconds of building a simplex tree 0.013689279556274414
# time of calculating barcodes  0.0006461143493652344
# time finish calculating rank invariance 0.21393370628356934
# total time for one elbow  0.22826910018920898
# elbow [1, 11]
# seconds of building a simplex tree 0.013695001602172852
# time of calculating barcodes  0.0005900859832763672
# time finish calculating rank invariance 0.20011687278747559
# total time for one elbow  0.2144019603729248
# elbow [2, 0]
# seconds of building a simplex tree 0.013980865478515625
# time of calculating barcodes  0.0008559226989746094
# time finish calculating rank invariance 0.19407105445861816
# total time for one elbow  0.2089078426361084
# elbow [2, 1]
# seconds of building a simplex tree 0.014056921005249023
# time of calculating barcodes  0.0008220672607421875
# time finish calculating rank invariance 0.21702098846435547
# total time for one elbow  0.23189997673034668
# elbow [2, 2]
# seconds of building a simplex tree 0.0181119441986084
# time of calculating barcodes  0.0007758140563964844
# time finish calculating rank invariance 0.21339917182922363
# total time for one elbow  0.23228693008422852
# elbow [2, 3]
# seconds of building a simplex tree 0.014488697052001953
# time of calculating barcodes  0.0007102489471435547
# time finish calculating rank invariance 0.19998478889465332
# total time for one elbow  0.21518373489379883
# elbow [2, 4]
# seconds of building a simplex tree 0.013731956481933594
# time of calculating barcodes  0.0008418560028076172
# time finish calculating rank invariance 0.1980891227722168
# total time for one elbow  0.212662935256958
# elbow [2, 5]
# seconds of building a simplex tree 0.014121055603027344
# time of calculating barcodes  0.0009951591491699219
# time finish calculating rank invariance 0.21246790885925293
# total time for one elbow  0.2275841236114502
# elbow [2, 6]
# seconds of building a simplex tree 0.014184951782226562
# time of calculating barcodes  0.0006649494171142578
# time finish calculating rank invariance 0.2033381462097168
# total time for one elbow  0.21818804740905762
# elbow [2, 7]
# seconds of building a simplex tree 0.014120817184448242
# time of calculating barcodes  0.0008509159088134766
# time finish calculating rank invariance 0.22329926490783691
# total time for one elbow  0.23827099800109863
# elbow [2, 8]
# seconds of building a simplex tree 0.01449894905090332
# time of calculating barcodes  0.0007398128509521484
# time finish calculating rank invariance 0.2063741683959961
# total time for one elbow  0.22161293029785156
# elbow [2, 9]
# seconds of building a simplex tree 0.013624191284179688
# time of calculating barcodes  0.0006747245788574219
# time finish calculating rank invariance 0.21084213256835938
# total time for one elbow  0.22514104843139648
# elbow [2, 10]
# seconds of building a simplex tree 0.014780282974243164
# time of calculating barcodes  0.0007448196411132812
# time finish calculating rank invariance 0.21191716194152832
# total time for one elbow  0.22744226455688477
# elbow [2, 11]
# seconds of building a simplex tree 0.015877723693847656
# time of calculating barcodes  0.0010004043579101562
# time finish calculating rank invariance 0.2032766342163086
# total time for one elbow  0.2201547622680664
# elbow [3, 0]
# seconds of building a simplex tree 0.015478134155273438
# time of calculating barcodes  0.0007007122039794922
# time finish calculating rank invariance 0.2045001983642578
# total time for one elbow  0.22067904472351074
# elbow [3, 1]
# seconds of building a simplex tree 0.016362905502319336
# time of calculating barcodes  0.0009810924530029297
# time finish calculating rank invariance 0.20438194274902344
# total time for one elbow  0.2217259407043457
# elbow [3, 2]
# seconds of building a simplex tree 0.014528989791870117
# time of calculating barcodes  0.0007078647613525391
# time finish calculating rank invariance 0.1941850185394287
# total time for one elbow  0.20942187309265137
# elbow [3, 3]
# seconds of building a simplex tree 0.01419687271118164
# time of calculating barcodes  0.0009081363677978516
# time finish calculating rank invariance 0.19765877723693848
# total time for one elbow  0.21276378631591797
# elbow [3, 4]
# seconds of building a simplex tree 0.014816045761108398
# time of calculating barcodes  0.0006170272827148438
# time finish calculating rank invariance 0.1942300796508789
# total time for one elbow  0.20966315269470215
# elbow [3, 5]
# seconds of building a simplex tree 0.014142751693725586
# time of calculating barcodes  0.0010662078857421875
# time finish calculating rank invariance 0.21552467346191406
# total time for one elbow  0.23073363304138184
# elbow [3, 6]
# seconds of building a simplex tree 0.0140228271484375
# time of calculating barcodes  0.0014579296112060547
# time finish calculating rank invariance 0.21769309043884277
# total time for one elbow  0.23317384719848633
# elbow [3, 7]
# seconds of building a simplex tree 0.013833999633789062
# time of calculating barcodes  0.0006561279296875
# time finish calculating rank invariance 0.20067381858825684
# total time for one elbow  0.2151639461517334
# elbow [3, 8]
# seconds of building a simplex tree 0.013761043548583984
# time of calculating barcodes  0.0006430149078369141
# time finish calculating rank invariance 0.21967077255249023
# total time for one elbow  0.23407483100891113
# elbow [3, 9]
# seconds of building a simplex tree 0.014295101165771484
# time of calculating barcodes  0.0009319782257080078
# time finish calculating rank invariance 0.21835803985595703
# total time for one elbow  0.23358511924743652
# elbow [3, 10]
# seconds of building a simplex tree 0.014792203903198242
# time of calculating barcodes  0.0008666515350341797
# time finish calculating rank invariance 0.2075791358947754
# total time for one elbow  0.2232379913330078
# elbow [3, 11]
# seconds of building a simplex tree 0.015234231948852539
# time of calculating barcodes  0.0006458759307861328
# time finish calculating rank invariance 0.20011305809020996
# total time for one elbow  0.21599316596984863
# elbow [4, 0]
# seconds of building a simplex tree 0.013983964920043945
# time of calculating barcodes  0.0006320476531982422
# time finish calculating rank invariance 0.2065720558166504
# total time for one elbow  0.22118806838989258
# elbow [4, 1]
# seconds of building a simplex tree 0.014845132827758789
# time of calculating barcodes  0.0005927085876464844
# time finish calculating rank invariance 0.20537114143371582
# total time for one elbow  0.2208089828491211
# elbow [4, 2]
# seconds of building a simplex tree 0.01585102081298828
# time of calculating barcodes  0.0007412433624267578
# time finish calculating rank invariance 0.20581984519958496
# total time for one elbow  0.222412109375
# elbow [4, 3]
# seconds of building a simplex tree 0.015458106994628906
# time of calculating barcodes  0.0006639957427978516
# time finish calculating rank invariance 0.2118978500366211
# total time for one elbow  0.22801995277404785
# elbow [4, 4]
# seconds of building a simplex tree 0.014024019241333008
# time of calculating barcodes  0.0006110668182373047
# time finish calculating rank invariance 0.1970219612121582
# total time for one elbow  0.21165704727172852
# elbow [4, 5]
# seconds of building a simplex tree 0.015365839004516602
# time of calculating barcodes  0.0006899833679199219
# time finish calculating rank invariance 0.21833419799804688
# total time for one elbow  0.2343900203704834
# elbow [4, 6]
# seconds of building a simplex tree 0.016334056854248047
# time of calculating barcodes  0.001013040542602539
# time finish calculating rank invariance 0.22779607772827148
# total time for one elbow  0.24514317512512207
# elbow [4, 7]
# seconds of building a simplex tree 0.014353275299072266
# time of calculating barcodes  0.0006089210510253906
# time finish calculating rank invariance 0.21382498741149902
# total time for one elbow  0.22878718376159668
# elbow [4, 8]
# seconds of building a simplex tree 0.015572786331176758
# time of calculating barcodes  0.0006611347198486328
# time finish calculating rank invariance 0.2064979076385498
# total time for one elbow  0.2227318286895752
# elbow [4, 9]
# seconds of building a simplex tree 0.014076948165893555
# time of calculating barcodes  0.0006861686706542969
# time finish calculating rank invariance 0.20186090469360352
# total time for one elbow  0.21662402153015137
# elbow [4, 10]
# seconds of building a simplex tree 0.01369619369506836
# time of calculating barcodes  0.0008990764617919922
# time finish calculating rank invariance 0.21287178993225098
# total time for one elbow  0.22746706008911133
# elbow [4, 11]
# seconds of building a simplex tree 0.014711141586303711
# time of calculating barcodes  0.0007390975952148438
# time finish calculating rank invariance 0.21244001388549805
# total time for one elbow  0.2278902530670166
# elbow [5, 0]
# seconds of building a simplex tree 0.014242172241210938
# time of calculating barcodes  0.0007240772247314453
# time finish calculating rank invariance 0.18610191345214844
# total time for one elbow  0.20106816291809082
# elbow [5, 1]
# seconds of building a simplex tree 0.015060901641845703
# time of calculating barcodes  0.0011582374572753906
# time finish calculating rank invariance 0.1929316520690918
# total time for one elbow  0.2091507911682129
# elbow [5, 2]
# seconds of building a simplex tree 0.01468205451965332
# time of calculating barcodes  0.0008389949798583984
# time finish calculating rank invariance 0.19718599319458008
# total time for one elbow  0.2127070426940918
# elbow [5, 3]
# seconds of building a simplex tree 0.016304969787597656
# time of calculating barcodes  0.0009491443634033203
# time finish calculating rank invariance 0.21300983428955078
# total time for one elbow  0.23026394844055176
# elbow [5, 4]
# seconds of building a simplex tree 0.015316009521484375
# time of calculating barcodes  0.001123189926147461
# time finish calculating rank invariance 0.21576404571533203
# total time for one elbow  0.23220324516296387
# elbow [5, 5]
# seconds of building a simplex tree 0.015687942504882812
# time of calculating barcodes  0.0006489753723144531
# time finish calculating rank invariance 0.20547008514404297
# total time for one elbow  0.22180700302124023
# elbow [5, 6]
# seconds of building a simplex tree 0.015326976776123047
# time of calculating barcodes  0.0006279945373535156
# time finish calculating rank invariance 0.2113358974456787
# total time for one elbow  0.22729086875915527
# elbow [5, 7]
# seconds of building a simplex tree 0.014890909194946289
# time of calculating barcodes  0.0006730556488037109
# time finish calculating rank invariance 0.21399903297424316
# total time for one elbow  0.22956299781799316
# elbow [5, 8]
# seconds of building a simplex tree 0.014937877655029297
# time of calculating barcodes  0.0008292198181152344
# time finish calculating rank invariance 0.19887185096740723
# total time for one elbow  0.21463894844055176
# elbow [5, 9]
# seconds of building a simplex tree 0.014167070388793945
# time of calculating barcodes  0.0005638599395751953
# time finish calculating rank invariance 0.21791791915893555
# total time for one elbow  0.2326488494873047
# elbow [5, 10]
# seconds of building a simplex tree 0.014985322952270508
# time of calculating barcodes  0.0006999969482421875
# time finish calculating rank invariance 0.22376179695129395
# total time for one elbow  0.23944711685180664
# elbow [5, 11]
# seconds of building a simplex tree 0.014499902725219727
# time of calculating barcodes  0.0007030963897705078
# time finish calculating rank invariance 0.22047185897827148
# total time for one elbow  0.23567485809326172
# elbow [6, 0]
# seconds of building a simplex tree 0.014515876770019531
# time of calculating barcodes  0.0007140636444091797
# time finish calculating rank invariance 0.18860483169555664
# total time for one elbow  0.20383477210998535
# elbow [6, 1]
# seconds of building a simplex tree 0.013993024826049805
# time of calculating barcodes  0.0008130073547363281
# time finish calculating rank invariance 0.1781010627746582
# total time for one elbow  0.19290709495544434
# elbow [6, 2]
# seconds of building a simplex tree 0.013926267623901367
# time of calculating barcodes  0.0006079673767089844
# time finish calculating rank invariance 0.18107104301452637
# total time for one elbow  0.19560527801513672
# elbow [6, 3]
# seconds of building a simplex tree 0.01386713981628418
# time of calculating barcodes  0.0006918907165527344
# time finish calculating rank invariance 0.17958307266235352
# total time for one elbow  0.19414210319519043
# elbow [6, 4]
# seconds of building a simplex tree 0.014068126678466797
# time of calculating barcodes  0.000701904296875
# time finish calculating rank invariance 0.18507003784179688
# total time for one elbow  0.19984006881713867
# elbow [6, 5]
# seconds of building a simplex tree 0.01386117935180664
# time of calculating barcodes  0.000705718994140625
# time finish calculating rank invariance 0.1878981590270996
# total time for one elbow  0.20246505737304688
# elbow [6, 6]
# seconds of building a simplex tree 0.013895273208618164
# time of calculating barcodes  0.0006148815155029297
# time finish calculating rank invariance 0.18991684913635254
# total time for one elbow  0.20442700386047363
# elbow [6, 7]
# seconds of building a simplex tree 0.013855934143066406
# time of calculating barcodes  0.0005948543548583984
# time finish calculating rank invariance 0.19161128997802734
# total time for one elbow  0.20606207847595215
# elbow [6, 8]
# seconds of building a simplex tree 0.013627052307128906
# time of calculating barcodes  0.0006659030914306641
# time finish calculating rank invariance 0.20415210723876953
# total time for one elbow  0.2184450626373291
# elbow [6, 9]
# seconds of building a simplex tree 0.01524209976196289
# time of calculating barcodes  0.0006327629089355469
# time finish calculating rank invariance 0.21593308448791504
# total time for one elbow  0.23180794715881348
# elbow [6, 10]
# seconds of building a simplex tree 0.013633012771606445
# time of calculating barcodes  0.0007300376892089844
# time finish calculating rank invariance 0.21199393272399902
# total time for one elbow  0.22635698318481445
# elbow [6, 11]
# seconds of building a simplex tree 0.014296770095825195
# time of calculating barcodes  0.0006608963012695312
# time finish calculating rank invariance 0.20016121864318848
# total time for one elbow  0.2151188850402832
# elbow [7, 0]
# seconds of building a simplex tree 0.013918876647949219
# time of calculating barcodes  0.0008831024169921875
# time finish calculating rank invariance 0.17301392555236816
# total time for one elbow  0.18781590461730957
# elbow [7, 1]
# seconds of building a simplex tree 0.013895988464355469
# time of calculating barcodes  0.0005710124969482422
# time finish calculating rank invariance 0.17382574081420898
# total time for one elbow  0.1882927417755127
# elbow [7, 2]
# seconds of building a simplex tree 0.013965845108032227
# time of calculating barcodes  0.0006911754608154297
# time finish calculating rank invariance 0.17573308944702148
# total time for one elbow  0.19039011001586914
# elbow [7, 3]
# seconds of building a simplex tree 0.013864994049072266
# time of calculating barcodes  0.0006031990051269531
# time finish calculating rank invariance 0.1773817539215088
# total time for one elbow  0.191849946975708
# elbow [7, 4]
# seconds of building a simplex tree 0.013907909393310547
# time of calculating barcodes  0.0006031990051269531
# time finish calculating rank invariance 0.1779158115386963
# total time for one elbow  0.1924269199371338
# elbow [7, 5]
# seconds of building a simplex tree 0.013822793960571289
# time of calculating barcodes  0.0008842945098876953
# time finish calculating rank invariance 0.18375778198242188
# total time for one elbow  0.19846487045288086
# elbow [7, 6]
# seconds of building a simplex tree 0.01385188102722168
# time of calculating barcodes  0.0006101131439208984
# time finish calculating rank invariance 0.1866922378540039
# total time for one elbow  0.20115423202514648
# elbow [7, 7]
# seconds of building a simplex tree 0.014636039733886719
# time of calculating barcodes  0.0006959438323974609
# time finish calculating rank invariance 0.1894690990447998
# total time for one elbow  0.20480108261108398
# elbow [7, 8]
# seconds of building a simplex tree 0.014036893844604492
# time of calculating barcodes  0.0006527900695800781
# time finish calculating rank invariance 0.19246840476989746
# total time for one elbow  0.20715808868408203
# elbow [7, 9]
# seconds of building a simplex tree 0.013966798782348633
# time of calculating barcodes  0.0007150173187255859
# time finish calculating rank invariance 0.19617700576782227
# total time for one elbow  0.21085882186889648
# elbow [7, 10]
# seconds of building a simplex tree 0.014083147048950195
# time of calculating barcodes  0.0006771087646484375
# time finish calculating rank invariance 0.19570088386535645
# total time for one elbow  0.21046113967895508
# elbow [7, 11]
# seconds of building a simplex tree 0.013982057571411133
# time of calculating barcodes  0.001035928726196289
# time finish calculating rank invariance 0.23691320419311523
# total time for one elbow  0.25193119049072266
# elbow [8, 0]
# seconds of building a simplex tree 0.014881134033203125
# time of calculating barcodes  0.0005769729614257812
# time finish calculating rank invariance 0.17297101020812988
# total time for one elbow  0.1884291172027588
# elbow [8, 1]
# seconds of building a simplex tree 0.013934135437011719
# time of calculating barcodes  0.0006148815155029297
# time finish calculating rank invariance 0.18083620071411133
# total time for one elbow  0.19538521766662598
# elbow [8, 2]
# seconds of building a simplex tree 0.013854026794433594
# time of calculating barcodes  0.0006070137023925781
# time finish calculating rank invariance 0.17395997047424316
# total time for one elbow  0.18842101097106934
# elbow [8, 3]
# seconds of building a simplex tree 0.013802051544189453
# time of calculating barcodes  0.000598907470703125
# time finish calculating rank invariance 0.17759418487548828
# total time for one elbow  0.19199514389038086
# elbow [8, 4]
# seconds of building a simplex tree 0.014134883880615234
# time of calculating barcodes  0.0006399154663085938
# time finish calculating rank invariance 0.18028998374938965
# total time for one elbow  0.19506478309631348
# elbow [8, 5]
# seconds of building a simplex tree 0.014139175415039062
# time of calculating barcodes  0.0008549690246582031
# time finish calculating rank invariance 0.18495392799377441
# total time for one elbow  0.19994807243347168
# elbow [8, 6]
# seconds of building a simplex tree 0.014026165008544922
# time of calculating barcodes  0.0006518363952636719
# time finish calculating rank invariance 0.18754005432128906
# total time for one elbow  0.20221805572509766
# elbow [8, 7]
# seconds of building a simplex tree 0.013991832733154297
# time of calculating barcodes  0.0006089210510253906
# time finish calculating rank invariance 0.19173407554626465
# total time for one elbow  0.20633482933044434
# elbow [8, 8]
# seconds of building a simplex tree 0.014027118682861328
# time of calculating barcodes  0.0005631446838378906
# time finish calculating rank invariance 0.19151806831359863
# total time for one elbow  0.20610833168029785
# elbow [8, 9]
# seconds of building a simplex tree 0.013997077941894531
# time of calculating barcodes  0.0011026859283447266
# time finish calculating rank invariance 0.19652915000915527
# total time for one elbow  0.21162891387939453
# elbow [8, 10]
# seconds of building a simplex tree 0.014497756958007812
# time of calculating barcodes  0.0006642341613769531
# time finish calculating rank invariance 0.19783592224121094
# total time for one elbow  0.2129979133605957
# elbow [8, 11]
# seconds of building a simplex tree 0.014094114303588867
# time of calculating barcodes  0.0009980201721191406
# time finish calculating rank invariance 0.20256495475769043
# total time for one elbow  0.21765708923339844
# elbow [9, 0]
# seconds of building a simplex tree 0.01397085189819336
# time of calculating barcodes  0.0009152889251708984
# time finish calculating rank invariance 0.17296171188354492
# total time for one elbow  0.18784785270690918
# elbow [9, 1]
# seconds of building a simplex tree 0.01397085189819336
# time of calculating barcodes  0.0006053447723388672
# time finish calculating rank invariance 0.1718888282775879
# total time for one elbow  0.18646502494812012
# elbow [9, 2]
# seconds of building a simplex tree 0.014077901840209961
# time of calculating barcodes  0.0005443096160888672
# time finish calculating rank invariance 0.1713106632232666
# total time for one elbow  0.18593287467956543
# elbow [9, 3]
# seconds of building a simplex tree 0.013912677764892578
# time of calculating barcodes  0.0005860328674316406
# time finish calculating rank invariance 0.17514419555664062
# total time for one elbow  0.18964290618896484
# elbow [9, 4]
# seconds of building a simplex tree 0.014067888259887695
# time of calculating barcodes  0.0006060600280761719
# time finish calculating rank invariance 0.17514586448669434
# total time for one elbow  0.1898198127746582
# elbow [9, 5]
# seconds of building a simplex tree 0.013921737670898438
# time of calculating barcodes  0.0006031990051269531
# time finish calculating rank invariance 0.18078207969665527
# total time for one elbow  0.19530701637268066
# elbow [9, 6]
# seconds of building a simplex tree 0.013980388641357422
# time of calculating barcodes  0.0006668567657470703
# time finish calculating rank invariance 0.1964430809020996
# total time for one elbow  0.2110903263092041
# elbow [9, 7]
# seconds of building a simplex tree 0.017033100128173828
# time of calculating barcodes  0.0010099411010742188
# time finish calculating rank invariance 0.2155132293701172
# total time for one elbow  0.23355627059936523
# elbow [9, 8]
# seconds of building a simplex tree 0.016623735427856445
# time of calculating barcodes  0.0009641647338867188
# time finish calculating rank invariance 0.2031240463256836
# total time for one elbow  0.22071194648742676
# elbow [9, 9]
# seconds of building a simplex tree 0.013874053955078125
# time of calculating barcodes  0.0008571147918701172
# time finish calculating rank invariance 0.1944277286529541
# total time for one elbow  0.20915889739990234
# elbow [9, 10]
# seconds of building a simplex tree 0.014213800430297852
# time of calculating barcodes  0.0006630420684814453
# time finish calculating rank invariance 0.19642019271850586
# total time for one elbow  0.21129703521728516
# elbow [9, 11]
# seconds of building a simplex tree 0.014487981796264648
# time of calculating barcodes  0.0007421970367431641
# time finish calculating rank invariance 0.20181798934936523
# total time for one elbow  0.21704816818237305
# elbow [10, 0]
# seconds of building a simplex tree 0.013791322708129883
# time of calculating barcodes  0.0008420944213867188
# time finish calculating rank invariance 0.17877984046936035
# total time for one elbow  0.19341325759887695
# elbow [10, 1]
# seconds of building a simplex tree 0.014280319213867188
# time of calculating barcodes  0.0006399154663085938
# time finish calculating rank invariance 0.167741060256958
# total time for one elbow  0.1826612949371338
# elbow [10, 2]
# seconds of building a simplex tree 0.013997077941894531
# time of calculating barcodes  0.0007081031799316406
# time finish calculating rank invariance 0.1691148281097412
# total time for one elbow  0.18382000923156738
# elbow [10, 3]
# seconds of building a simplex tree 0.013978958129882812
# time of calculating barcodes  0.0006020069122314453
# time finish calculating rank invariance 0.1708381175994873
# total time for one elbow  0.18541908264160156
# elbow [10, 4]
# seconds of building a simplex tree 0.013931035995483398
# time of calculating barcodes  0.0005557537078857422
# time finish calculating rank invariance 0.17166423797607422
# total time for one elbow  0.18615102767944336
# elbow [10, 5]
# seconds of building a simplex tree 0.013915777206420898
# time of calculating barcodes  0.0005571842193603516
# time finish calculating rank invariance 0.1774458885192871
# total time for one elbow  0.19191884994506836
# elbow [10, 6]
# seconds of building a simplex tree 0.01404881477355957
# time of calculating barcodes  0.0006020069122314453
# time finish calculating rank invariance 0.17970800399780273
# total time for one elbow  0.19435882568359375
# elbow [10, 7]
# seconds of building a simplex tree 0.014245748519897461
# time of calculating barcodes  0.0007328987121582031
# time finish calculating rank invariance 0.18415307998657227
# total time for one elbow  0.19913172721862793
# elbow [10, 8]
# seconds of building a simplex tree 0.014158964157104492
# time of calculating barcodes  0.0006098747253417969
# time finish calculating rank invariance 0.18866610527038574
# total time for one elbow  0.20343494415283203
# elbow [10, 9]
# seconds of building a simplex tree 0.014065980911254883
# time of calculating barcodes  0.0005431175231933594
# time finish calculating rank invariance 0.1876678466796875
# total time for one elbow  0.20227694511413574
# elbow [10, 10]
# seconds of building a simplex tree 0.01419210433959961
# time of calculating barcodes  0.0008599758148193359
# time finish calculating rank invariance 0.19284296035766602
# total time for one elbow  0.20789504051208496
# elbow [10, 11]
# seconds of building a simplex tree 0.01403498649597168
# time of calculating barcodes  0.0007050037384033203
# time finish calculating rank invariance 0.20839715003967285
# total time for one elbow  0.22313714027404785
# elbow [11, 0]
# seconds of building a simplex tree 0.016334056854248047
# time of calculating barcodes  0.0007669925689697266
# time finish calculating rank invariance 0.18871402740478516
# total time for one elbow  0.20581507682800293
# elbow [11, 1]
# seconds of building a simplex tree 0.01792311668395996
# time of calculating barcodes  0.0016660690307617188
# time finish calculating rank invariance 0.1717519760131836
# total time for one elbow  0.19134116172790527
# elbow [11, 2]
# seconds of building a simplex tree 0.014675140380859375
# time of calculating barcodes  0.0005819797515869141
# time finish calculating rank invariance 0.1684129238128662
# total time for one elbow  0.1836700439453125
# elbow [11, 3]
# seconds of building a simplex tree 0.014060020446777344
# time of calculating barcodes  0.0007219314575195312
# time finish calculating rank invariance 0.1660771369934082
# total time for one elbow  0.18085908889770508
# elbow [11, 4]
# seconds of building a simplex tree 0.014191150665283203
# time of calculating barcodes  0.0006139278411865234
# time finish calculating rank invariance 0.19987988471984863
# total time for one elbow  0.21468496322631836
# elbow [11, 5]
# seconds of building a simplex tree 0.015413761138916016
# time of calculating barcodes  0.0008640289306640625
# time finish calculating rank invariance 0.18787217140197754
# total time for one elbow  0.20414996147155762
# elbow [11, 6]
# seconds of building a simplex tree 0.01554727554321289
# time of calculating barcodes  0.0006940364837646484
# time finish calculating rank invariance 0.19104981422424316
# total time for one elbow  0.2072911262512207
# elbow [11, 7]
# seconds of building a simplex tree 0.014085769653320312
# time of calculating barcodes  0.0007481575012207031
# time finish calculating rank invariance 0.18321609497070312
# total time for one elbow  0.19805002212524414
# elbow [11, 8]
# seconds of building a simplex tree 0.01924419403076172
# time of calculating barcodes  0.0012028217315673828
# time finish calculating rank invariance 0.19930696487426758
# total time for one elbow  0.21975398063659668
# elbow [11, 9]
# seconds of building a simplex tree 0.016097068786621094
# time of calculating barcodes  0.0008840560913085938
# time finish calculating rank invariance 0.2345719337463379
# total time for one elbow  0.2515530586242676
# elbow [11, 10]
# seconds of building a simplex tree 0.0167081356048584
# time of calculating barcodes  0.0006778240203857422
# time finish calculating rank invariance 0.19910120964050293
# total time for one elbow  0.21648716926574707
# elbow [11, 11]
# seconds of building a simplex tree 0.014993906021118164
# time of calculating barcodes  0.0008111000061035156
# time finish calculating rank invariance 0.21488714218139648
# total time for one elbow  0.23069214820861816
# elbow [12, 0]
# seconds of building a simplex tree 0.014534950256347656
# time of calculating barcodes  0.0007691383361816406
# time finish calculating rank invariance 0.1711277961730957
# total time for one elbow  0.186431884765625
# elbow [12, 1]
# seconds of building a simplex tree 0.015989065170288086
# time of calculating barcodes  0.0006639957427978516
# time finish calculating rank invariance 0.16789507865905762
# total time for one elbow  0.18454813957214355
# elbow [12, 2]
# seconds of building a simplex tree 0.013956069946289062
# time of calculating barcodes  0.0006096363067626953
# time finish calculating rank invariance 0.17717409133911133
# total time for one elbow  0.19173979759216309
# elbow [12, 3]
# seconds of building a simplex tree 0.017341136932373047
# time of calculating barcodes  0.0009069442749023438
# time finish calculating rank invariance 0.18303489685058594
# total time for one elbow  0.20128297805786133
# elbow [12, 4]
# seconds of building a simplex tree 0.014777898788452148
# time of calculating barcodes  0.0006959438323974609
# time finish calculating rank invariance 0.18444204330444336
# total time for one elbow  0.19991588592529297
# elbow [12, 5]
# seconds of building a simplex tree 0.015264034271240234
# time of calculating barcodes  0.0007250308990478516
# time finish calculating rank invariance 0.18360304832458496
# total time for one elbow  0.19959211349487305
# elbow [12, 6]
# seconds of building a simplex tree 0.016617774963378906
# time of calculating barcodes  0.0013232231140136719
# time finish calculating rank invariance 0.19372272491455078
# total time for one elbow  0.21166372299194336
# elbow [12, 7]
# seconds of building a simplex tree 0.014206886291503906
# time of calculating barcodes  0.0009121894836425781
# time finish calculating rank invariance 0.19824886322021484
# total time for one elbow  0.21336793899536133
# elbow [12, 8]
# seconds of building a simplex tree 0.016047000885009766
# time of calculating barcodes  0.0009312629699707031
# time finish calculating rank invariance 0.19757986068725586
# total time for one elbow  0.21455812454223633
# elbow [12, 9]
# seconds of building a simplex tree 0.014599800109863281
# time of calculating barcodes  0.0007643699645996094
# time finish calculating rank invariance 0.18960976600646973
# total time for one elbow  0.20497393608093262
# elbow [12, 10]
# seconds of building a simplex tree 0.014050960540771484
# time of calculating barcodes  0.0007040500640869141
# time finish calculating rank invariance 0.1914958953857422
# total time for one elbow  0.20625090599060059
# elbow [12, 11]
# seconds of building a simplex tree 0.014217138290405273
# time of calculating barcodes  0.0005888938903808594
# time finish calculating rank invariance 0.2053060531616211
# total time for one elbow  0.22011208534240723
# elbow [13, 0]
# seconds of building a simplex tree 0.014631032943725586
# time of calculating barcodes  0.0006668567657470703
# time finish calculating rank invariance 0.17130327224731445
# total time for one elbow  0.1866011619567871
# elbow [13, 1]
# seconds of building a simplex tree 0.014899969100952148
# time of calculating barcodes  0.0010809898376464844
# time finish calculating rank invariance 0.16972923278808594
# total time for one elbow  0.18571019172668457
# elbow [13, 2]
# seconds of building a simplex tree 0.015086174011230469
# time of calculating barcodes  0.0011148452758789062
# time finish calculating rank invariance 0.18486809730529785
# total time for one elbow  0.20106911659240723
# elbow [13, 3]
# seconds of building a simplex tree 0.013997077941894531
# time of calculating barcodes  0.0006577968597412109
# time finish calculating rank invariance 0.16468501091003418
# total time for one elbow  0.17933988571166992
# elbow [13, 4]
# seconds of building a simplex tree 0.015608072280883789
# time of calculating barcodes  0.0014071464538574219
# time finish calculating rank invariance 0.1820828914642334
# total time for one elbow  0.1990981101989746
# elbow [13, 5]
# seconds of building a simplex tree 0.014219999313354492
# time of calculating barcodes  0.0005509853363037109
# time finish calculating rank invariance 0.16964983940124512
# total time for one elbow  0.18442082405090332
# elbow [13, 6]
# seconds of building a simplex tree 0.01621103286743164
# time of calculating barcodes  0.0006308555603027344
# time finish calculating rank invariance 0.1698002815246582
# total time for one elbow  0.18664216995239258
# elbow [13, 7]
# seconds of building a simplex tree 0.015242815017700195
# time of calculating barcodes  0.0006539821624755859
# time finish calculating rank invariance 0.20232892036437988
# total time for one elbow  0.21822571754455566
# elbow [13, 8]
# seconds of building a simplex tree 0.024979829788208008
# time of calculating barcodes  0.0009632110595703125
# time finish calculating rank invariance 0.19133782386779785
# total time for one elbow  0.21728086471557617
# elbow [13, 9]
# seconds of building a simplex tree 0.014329910278320312
# time of calculating barcodes  0.0007622241973876953
# time finish calculating rank invariance 0.18563580513000488
# total time for one elbow  0.2007279396057129
# elbow [13, 10]
# seconds of building a simplex tree 0.014188051223754883
# time of calculating barcodes  0.0009889602661132812
# time finish calculating rank invariance 0.22307705879211426
# total time for one elbow  0.23825407028198242
# elbow [13, 11]
# seconds of building a simplex tree 0.01901388168334961
# time of calculating barcodes  0.0010612010955810547
# time finish calculating rank invariance 0.23411774635314941
# total time for one elbow  0.2541928291320801
# elbow [14, 0]
# seconds of building a simplex tree 0.014000177383422852
# time of calculating barcodes  0.0009729862213134766
# time finish calculating rank invariance 0.15658974647521973
# total time for one elbow  0.17156291007995605
# elbow [14, 1]
# seconds of building a simplex tree 0.014189004898071289
# time of calculating barcodes  0.0005609989166259766
# time finish calculating rank invariance 0.1719810962677002
# total time for one elbow  0.18673110008239746
# elbow [14, 2]
# seconds of building a simplex tree 0.014796018600463867
# time of calculating barcodes  0.0006031990051269531
# time finish calculating rank invariance 0.16062164306640625
# total time for one elbow  0.17602086067199707
# elbow [14, 3]
# seconds of building a simplex tree 0.014062166213989258
# time of calculating barcodes  0.0006058216094970703
# time finish calculating rank invariance 0.1602029800415039
# total time for one elbow  0.17487096786499023
# elbow [14, 4]
# seconds of building a simplex tree 0.014355897903442383
# time of calculating barcodes  0.0006511211395263672
# time finish calculating rank invariance 0.15747880935668945
# total time for one elbow  0.1724858283996582
# elbow [14, 5]
# seconds of building a simplex tree 0.013926982879638672
# time of calculating barcodes  0.0006048679351806641
# time finish calculating rank invariance 0.1681201457977295
# total time for one elbow  0.18265199661254883
# elbow [14, 6]
# seconds of building a simplex tree 0.018531084060668945
# time of calculating barcodes  0.0006511211395263672
# time finish calculating rank invariance 0.17283987998962402
# total time for one elbow  0.19202208518981934
# elbow [14, 7]
# seconds of building a simplex tree 0.013910055160522461
# time of calculating barcodes  0.0007789134979248047
# time finish calculating rank invariance 0.17058420181274414
# total time for one elbow  0.1852731704711914
# elbow [14, 8]
# seconds of building a simplex tree 0.013958930969238281
# time of calculating barcodes  0.0006039142608642578
# time finish calculating rank invariance 0.17526507377624512
# total time for one elbow  0.18982791900634766
# elbow [14, 9]
# seconds of building a simplex tree 0.014528989791870117
# time of calculating barcodes  0.0006258487701416016
# time finish calculating rank invariance 0.19211626052856445
# total time for one elbow  0.20727109909057617
# elbow [14, 10]
# seconds of building a simplex tree 0.015530109405517578
# time of calculating barcodes  0.0006778240203857422
# time finish calculating rank invariance 0.18999123573303223
# total time for one elbow  0.20619916915893555
# elbow [14, 11]
# seconds of building a simplex tree 0.0157012939453125
# time of calculating barcodes  0.0007870197296142578
# time finish calculating rank invariance 0.22248291969299316
# total time for one elbow  0.23897123336791992
# elbow [15, 0]
# seconds of building a simplex tree 0.01410675048828125
# time of calculating barcodes  0.0006451606750488281
# time finish calculating rank invariance 0.15683507919311523
# total time for one elbow  0.1715869903564453
# elbow [15, 1]
# seconds of building a simplex tree 0.014053106307983398
# time of calculating barcodes  0.0006000995635986328
# time finish calculating rank invariance 0.16251683235168457
# total time for one elbow  0.1771700382232666
# elbow [15, 2]
# seconds of building a simplex tree 0.014597177505493164
# time of calculating barcodes  0.0006010532379150391
# time finish calculating rank invariance 0.19965505599975586
# total time for one elbow  0.21485328674316406
# elbow [15, 3]
# seconds of building a simplex tree 0.014690637588500977
# time of calculating barcodes  0.0007202625274658203
# time finish calculating rank invariance 0.15961694717407227
# total time for one elbow  0.17502784729003906
# elbow [15, 4]
# seconds of building a simplex tree 0.014009952545166016
# time of calculating barcodes  0.0006041526794433594
# time finish calculating rank invariance 0.16270995140075684
# total time for one elbow  0.1773240566253662
# elbow [15, 5]
# seconds of building a simplex tree 0.030389070510864258
# time of calculating barcodes  0.0020227432250976562
# time finish calculating rank invariance 0.16857218742370605
# total time for one elbow  0.20098400115966797
# elbow [15, 6]
# seconds of building a simplex tree 0.015134096145629883
# time of calculating barcodes  0.0006737709045410156
# time finish calculating rank invariance 0.17500019073486328
# total time for one elbow  0.19080805778503418
# elbow [15, 7]
# seconds of building a simplex tree 0.015153884887695312
# time of calculating barcodes  0.0006582736968994141
# time finish calculating rank invariance 0.18378281593322754
# total time for one elbow  0.19959497451782227
# elbow [15, 8]
# seconds of building a simplex tree 0.014907121658325195
# time of calculating barcodes  0.0006227493286132812
# time finish calculating rank invariance 0.1782090663909912
# total time for one elbow  0.1937389373779297
# elbow [15, 9]
# seconds of building a simplex tree 0.015126943588256836
# time of calculating barcodes  0.0011148452758789062
# time finish calculating rank invariance 0.18454408645629883
# total time for one elbow  0.20078587532043457
# elbow [15, 10]
# seconds of building a simplex tree 0.014898061752319336
# time of calculating barcodes  0.0007619857788085938
# time finish calculating rank invariance 0.22276997566223145
# total time for one elbow  0.23843002319335938
# elbow [15, 11]
# seconds of building a simplex tree 0.014798164367675781
# time of calculating barcodes  0.0006778240203857422
# time finish calculating rank invariance 0.20371603965759277
# total time for one elbow  0.2191920280456543
# elbow [16, 0]
# seconds of building a simplex tree 0.013794898986816406
# time of calculating barcodes  0.0006771087646484375
# time finish calculating rank invariance 0.1471407413482666
# total time for one elbow  0.16161274909973145
# elbow [16, 1]
# seconds of building a simplex tree 0.015169858932495117
# time of calculating barcodes  0.0006089210510253906
# time finish calculating rank invariance 0.1450800895690918
# total time for one elbow  0.1608588695526123
# elbow [16, 2]
# seconds of building a simplex tree 0.013900995254516602
# time of calculating barcodes  0.0006041526794433594
# time finish calculating rank invariance 0.1509559154510498
# total time for one elbow  0.16546106338500977
# elbow [16, 3]
# seconds of building a simplex tree 0.015172719955444336
# time of calculating barcodes  0.0006711483001708984
# time finish calculating rank invariance 0.15657687187194824
# total time for one elbow  0.17242074012756348
# elbow [16, 4]
# seconds of building a simplex tree 0.014579296112060547
# time of calculating barcodes  0.0006058216094970703
# time finish calculating rank invariance 0.15777111053466797
# total time for one elbow  0.17295622825622559
# elbow [16, 5]
# seconds of building a simplex tree 0.01398611068725586
# time of calculating barcodes  0.0005359649658203125
# time finish calculating rank invariance 0.15865087509155273
# total time for one elbow  0.1731729507446289
# elbow [16, 6]
# seconds of building a simplex tree 0.013976812362670898
# time of calculating barcodes  0.0006489753723144531
# time finish calculating rank invariance 0.16145110130310059
# total time for one elbow  0.17607688903808594
# elbow [16, 7]
# seconds of building a simplex tree 0.014034271240234375
# time of calculating barcodes  0.0005970001220703125
# time finish calculating rank invariance 0.16603994369506836
# total time for one elbow  0.18067121505737305
# elbow [16, 8]
# seconds of building a simplex tree 0.01460409164428711
# time of calculating barcodes  0.0006089210510253906
# time finish calculating rank invariance 0.17556381225585938
# total time for one elbow  0.19077682495117188
# elbow [16, 9]
# seconds of building a simplex tree 0.018944978713989258
# time of calculating barcodes  0.0008788108825683594
# time finish calculating rank invariance 0.18854498863220215
# total time for one elbow  0.20836877822875977
# elbow [16, 10]
# seconds of building a simplex tree 0.015825986862182617
# time of calculating barcodes  0.0007710456848144531
# time finish calculating rank invariance 0.17094707489013672
# total time for one elbow  0.1875441074371338
# elbow [16, 11]
# seconds of building a simplex tree 0.013786077499389648
# time of calculating barcodes  0.0005562305450439453
# time finish calculating rank invariance 0.20519185066223145
# total time for one elbow  0.21953415870666504
# elbow [17, 0]
# seconds of building a simplex tree 0.014502286911010742
# time of calculating barcodes  0.0006039142608642578
# time finish calculating rank invariance 0.16200685501098633
# total time for one elbow  0.17711305618286133
# elbow [17, 1]
# seconds of building a simplex tree 0.022344112396240234
# time of calculating barcodes  0.0009088516235351562
# time finish calculating rank invariance 0.15834617614746094
# total time for one elbow  0.18159914016723633
# elbow [17, 2]
# seconds of building a simplex tree 0.014220952987670898
# time of calculating barcodes  0.0005509853363037109
# time finish calculating rank invariance 0.14820599555969238
# total time for one elbow  0.162977933883667
# elbow [17, 3]
# seconds of building a simplex tree 0.013999223709106445
# time of calculating barcodes  0.0005791187286376953
# time finish calculating rank invariance 0.15090465545654297
# total time for one elbow  0.1654829978942871
# elbow [17, 4]
# seconds of building a simplex tree 0.013891220092773438
# time of calculating barcodes  0.0005009174346923828
# time finish calculating rank invariance 0.1494898796081543
# total time for one elbow  0.16388201713562012
# elbow [17, 5]
# seconds of building a simplex tree 0.014033079147338867
# time of calculating barcodes  0.0006039142608642578
# time finish calculating rank invariance 0.15496492385864258
# total time for one elbow  0.1696019172668457
# elbow [17, 6]
# seconds of building a simplex tree 0.014045953750610352
# time of calculating barcodes  0.0005948543548583984
# time finish calculating rank invariance 0.15602993965148926
# total time for one elbow  0.170670747756958
# elbow [17, 7]
# seconds of building a simplex tree 0.01569509506225586
# time of calculating barcodes  0.0006968975067138672
# ...
# time finish calculating rank invariance 0.12951993942260742
# total time for one elbow  0.14417600631713867
# elbow [29, 4]
# seconds of building a simplex tree 0.015107870101928711
# time of calculating barcodes  0.0006279945373535156
# time finish calculating rank invariance 0.13433384895324707
# total time for one elbow  0.1500697135925293
# elbow [29, 5]
# seconds of building a simplex tree 0.013985157012939453
# time of calculating barcodes  0.0007989406585693359
# time finish calculating rank invariance 0.13378000259399414
# total time for one elbow  0.14856410026550293
# elbow [29, 6]
# seconds of building a simplex tree 0.013992786407470703
# time of calculating barcodes  0.0006022453308105469
# time finish calculating rank invariance 0.14767193794250488
# total time for one elbow  0.16226696968078613
# elbow [29, 7]
# seconds of building a simplex tree 0.017180919647216797
# time of calculating barcodes  0.0007169246673583984
# time finish calculating rank invariance 0.16527509689331055
# total time for one elbow  0.18317294120788574
# elbow [29, 8]
# seconds of building a simplex tree 0.015522003173828125
# time of calculating barcodes  0.0006740093231201172
# time finish calculating rank invariance 0.14525079727172852
# total time for one elbow  0.16144680976867676
# elbow [29, 9]
# seconds of building a simplex tree 0.013985157012939453
# time of calculating barcodes  0.0006327629089355469
# time finish calculating rank invariance 0.15335702896118164
# total time for one elbow  0.16797494888305664
# elbow [29, 10]
# seconds of building a simplex tree 0.013942956924438477
# time of calculating barcodes  0.0006070137023925781
# time finish calculating rank invariance 0.1504819393157959
# total time for one elbow  0.16503190994262695
# elbow [29, 11]
# seconds of building a simplex tree 0.014031171798706055
# time of calculating barcodes  0.0005748271942138672
# time finish calculating rank invariance 0.2175440788269043
# total time for one elbow  0.23215007781982422
# elbow [30, 0]
# seconds of building a simplex tree 0.014338970184326172
# time of calculating barcodes  0.0005702972412109375
# time finish calculating rank invariance 0.11832499504089355
# total time for one elbow  0.13323426246643066
# elbow [30, 1]
# seconds of building a simplex tree 0.017267227172851562
# time of calculating barcodes  0.0006008148193359375
# time finish calculating rank invariance 0.127608060836792
# total time for one elbow  0.1454761028289795
# elbow [30, 2]
# seconds of building a simplex tree 0.014477968215942383
# time of calculating barcodes  0.0012290477752685547
# time finish calculating rank invariance 0.12848615646362305
# total time for one elbow  0.14419317245483398
# elbow [30, 3]
# seconds of building a simplex tree 0.014013290405273438
# time of calculating barcodes  0.0005869865417480469
# time finish calculating rank invariance 0.12381958961486816
# total time for one elbow  0.13841986656188965
# elbow [30, 4]
# seconds of building a simplex tree 0.014219045639038086
# time of calculating barcodes  0.0006000995635986328
# time finish calculating rank invariance 0.13266301155090332
# total time for one elbow  0.14748215675354004
# elbow [30, 5]
# seconds of building a simplex tree 0.015036821365356445
# time of calculating barcodes  0.0008640289306640625
# time finish calculating rank invariance 0.13266587257385254
# total time for one elbow  0.14856672286987305
# elbow [30, 6]
# seconds of building a simplex tree 0.014159679412841797
# time of calculating barcodes  0.0006041526794433594
# time finish calculating rank invariance 0.13399505615234375
# total time for one elbow  0.1487588882446289
# elbow [30, 7]
# seconds of building a simplex tree 0.014245033264160156
# time of calculating barcodes  0.0005838871002197266
# time finish calculating rank invariance 0.14667320251464844
# total time for one elbow  0.16150212287902832
# elbow [30, 8]
# seconds of building a simplex tree 0.014691829681396484
# time of calculating barcodes  0.0007979869842529297
# time finish calculating rank invariance 0.16683411598205566
# total time for one elbow  0.18232393264770508
# elbow [30, 9]
# seconds of building a simplex tree 0.01932692527770996
# time of calculating barcodes  0.00098419189453125
# time finish calculating rank invariance 0.15712881088256836
# total time for one elbow  0.17743992805480957
# elbow [30, 10]
# seconds of building a simplex tree 0.014039039611816406
# time of calculating barcodes  0.0005340576171875
# time finish calculating rank invariance 0.14956283569335938
# total time for one elbow  0.16413593292236328
# elbow [30, 11]
# seconds of building a simplex tree 0.01765298843383789
# time of calculating barcodes  0.0006918907165527344
# time finish calculating rank invariance 0.21454906463623047
# total time for one elbow  0.2328939437866211
# elbow [31, 0]
# seconds of building a simplex tree 0.016419172286987305
# time of calculating barcodes  0.0006878376007080078
# time finish calculating rank invariance 0.12507891654968262
# total time for one elbow  0.14218592643737793
# elbow [31, 1]
# seconds of building a simplex tree 0.015218019485473633
# time of calculating barcodes  0.0005469322204589844
# time finish calculating rank invariance 0.12583398818969727
# total time for one elbow  0.14159893989562988
# elbow [31, 2]
# seconds of building a simplex tree 0.015718936920166016
# time of calculating barcodes  0.0006320476531982422
# time finish calculating rank invariance 0.1436767578125
# total time for one elbow  0.16002774238586426
# elbow [31, 3]
# seconds of building a simplex tree 0.017993927001953125
# time of calculating barcodes  0.0007190704345703125
# time finish calculating rank invariance 0.12904906272888184
# total time for one elbow  0.14776206016540527
# elbow [31, 4]
# seconds of building a simplex tree 0.014282941818237305
# time of calculating barcodes  0.0007119178771972656
# time finish calculating rank invariance 0.12573719024658203
# total time for one elbow  0.1407320499420166
# elbow [31, 5]
# seconds of building a simplex tree 0.014433860778808594
# time of calculating barcodes  0.0005979537963867188
# time finish calculating rank invariance 0.13369417190551758
# total time for one elbow  0.1487259864807129
# elbow [31, 6]
# seconds of building a simplex tree 0.018403053283691406
# time of calculating barcodes  0.0009438991546630859
# time finish calculating rank invariance 0.20959186553955078
# total time for one elbow  0.22893881797790527
# elbow [31, 7]
# seconds of building a simplex tree 0.016623258590698242
# time of calculating barcodes  0.0008759498596191406
# time finish calculating rank invariance 0.14890670776367188
# total time for one elbow  0.16640591621398926
# elbow [31, 8]
# seconds of building a simplex tree 0.017004013061523438
# time of calculating barcodes  0.0006868839263916016
# time finish calculating rank invariance 0.19285202026367188
# total time for one elbow  0.21054291725158691
# elbow [31, 9]
# seconds of building a simplex tree 0.01611924171447754
# time of calculating barcodes  0.0006866455078125
# time finish calculating rank invariance 0.16032934188842773
# total time for one elbow  0.17713522911071777
# elbow [31, 10]
# seconds of building a simplex tree 0.01439809799194336
# time of calculating barcodes  0.0006337165832519531
# time finish calculating rank invariance 0.15102100372314453
# total time for one elbow  0.16605281829833984
# elbow [31, 11]
# seconds of building a simplex tree 0.014541149139404297
# time of calculating barcodes  0.0006718635559082031
# time finish calculating rank invariance 0.23510313034057617
# total time for one elbow  0.25031614303588867
# elbow [32, 0]
# seconds of building a simplex tree 0.015163898468017578
# time of calculating barcodes  0.0007739067077636719
# time finish calculating rank invariance 0.12046313285827637
# total time for one elbow  0.13640093803405762
# elbow [32, 1]
# seconds of building a simplex tree 0.01863384246826172
# time of calculating barcodes  0.001116037368774414
# time finish calculating rank invariance 0.13466215133666992
# total time for one elbow  0.15441203117370605
# elbow [32, 2]
# seconds of building a simplex tree 0.014330863952636719
# time of calculating barcodes  0.0006048679351806641
# time finish calculating rank invariance 0.12804198265075684
# total time for one elbow  0.14297771453857422
# elbow [32, 3]
# seconds of building a simplex tree 0.01574087142944336
# time of calculating barcodes  0.0006530284881591797
# time finish calculating rank invariance 0.12787508964538574
# total time for one elbow  0.14426898956298828
# elbow [32, 4]
# seconds of building a simplex tree 0.014984846115112305
# time of calculating barcodes  0.0006830692291259766
# time finish calculating rank invariance 0.13870596885681152
# total time for one elbow  0.1543738842010498
# elbow [32, 5]
# seconds of building a simplex tree 0.015921831130981445
# time of calculating barcodes  0.0008111000061035156
# time finish calculating rank invariance 0.15153980255126953
# total time for one elbow  0.1682727336883545
# elbow [32, 6]
# seconds of building a simplex tree 0.015959739685058594
# time of calculating barcodes  0.0008111000061035156
# time finish calculating rank invariance 0.13869190216064453
# total time for one elbow  0.15546274185180664
# elbow [32, 7]
# seconds of building a simplex tree 0.014626026153564453
# time of calculating barcodes  0.0006320476531982422
# time finish calculating rank invariance 0.1493978500366211
# total time for one elbow  0.1646559238433838
# elbow [32, 8]
# seconds of building a simplex tree 0.015746116638183594
# time of calculating barcodes  0.00090789794921875
# time finish calculating rank invariance 0.15360212326049805
# total time for one elbow  0.1702561378479004
# elbow [32, 9]
# seconds of building a simplex tree 0.014108896255493164
# time of calculating barcodes  0.0006499290466308594
# time finish calculating rank invariance 0.15155696868896484
# total time for one elbow  0.16631579399108887
# elbow [32, 10]
# seconds of building a simplex tree 0.015972137451171875
# time of calculating barcodes  0.0009169578552246094
# time finish calculating rank invariance 0.16302180290222168
# total time for one elbow  0.17991089820861816
# elbow [32, 11]
# seconds of building a simplex tree 0.015419721603393555
# time of calculating barcodes  0.0010981559753417969
# time finish calculating rank invariance 0.22158193588256836
# total time for one elbow  0.2380998134613037
# elbow [33, 0]
# seconds of building a simplex tree 0.014352083206176758
# time of calculating barcodes  0.0005910396575927734
# time finish calculating rank invariance 0.11360406875610352
# total time for one elbow  0.12854719161987305
# elbow [33, 1]
# seconds of building a simplex tree 0.01757502555847168
# time of calculating barcodes  0.0006320476531982422
# time finish calculating rank invariance 0.13160181045532227
# total time for one elbow  0.1498088836669922
# elbow [33, 2]
# seconds of building a simplex tree 0.021564006805419922
# time of calculating barcodes  0.0006411075592041016
# time finish calculating rank invariance 0.12346076965332031
# total time for one elbow  0.14566588401794434
# elbow [33, 3]
# seconds of building a simplex tree 0.014945030212402344
# time of calculating barcodes  0.0007081031799316406
# time finish calculating rank invariance 0.1237339973449707
# total time for one elbow  0.1393871307373047
# elbow [33, 4]
# seconds of building a simplex tree 0.014325141906738281
# time of calculating barcodes  0.0006060600280761719
# time finish calculating rank invariance 0.12474489212036133
# total time for one elbow  0.13967609405517578
# elbow [33, 5]
# seconds of building a simplex tree 0.014155864715576172
# time of calculating barcodes  0.0006082057952880859
# time finish calculating rank invariance 0.1394345760345459
# total time for one elbow  0.15419864654541016
# elbow [33, 6]
# seconds of building a simplex tree 0.015730857849121094
# time of calculating barcodes  0.0008771419525146484
# time finish calculating rank invariance 0.13893699645996094
# total time for one elbow  0.15554499626159668
# elbow [33, 7]
# seconds of building a simplex tree 0.014095783233642578
# time of calculating barcodes  0.0005381107330322266
# time finish calculating rank invariance 0.13920283317565918
# total time for one elbow  0.15383672714233398
# elbow [33, 8]
# seconds of building a simplex tree 0.015317916870117188
# time of calculating barcodes  0.0006520748138427734
# time finish calculating rank invariance 0.15748095512390137
# total time for one elbow  0.17345094680786133
# elbow [33, 9]
# seconds of building a simplex tree 0.015717029571533203
# time of calculating barcodes  0.0007970333099365234
# time finish calculating rank invariance 0.15628385543823242
# total time for one elbow  0.17279791831970215
# elbow [33, 10]
# seconds of building a simplex tree 0.015112876892089844
# time of calculating barcodes  0.0009691715240478516
# time finish calculating rank invariance 0.14668989181518555
# total time for one elbow  0.16277194023132324
# elbow [33, 11]
# seconds of building a simplex tree 0.014191150665283203
# time of calculating barcodes  0.0006847381591796875
# time finish calculating rank invariance 0.21246838569641113
# total time for one elbow  0.22734427452087402
# elbow [34, 0]
# seconds of building a simplex tree 0.016078710556030273
# time of calculating barcodes  0.0007050037384033203
# time finish calculating rank invariance 0.12950921058654785
# total time for one elbow  0.14629292488098145
# elbow [34, 1]
# seconds of building a simplex tree 0.01632404327392578
# time of calculating barcodes  0.0006868839263916016
# time finish calculating rank invariance 0.13138103485107422
# total time for one elbow  0.1483919620513916
# elbow [34, 2]
# seconds of building a simplex tree 0.014667034149169922
# time of calculating barcodes  0.0006041526794433594
# time finish calculating rank invariance 0.1300828456878662
# total time for one elbow  0.1453540325164795
# elbow [34, 3]
# seconds of building a simplex tree 0.016589879989624023
# time of calculating barcodes  0.0007579326629638672
# time finish calculating rank invariance 0.13485217094421387
# total time for one elbow  0.15219998359680176
# elbow [34, 4]
# seconds of building a simplex tree 0.01581406593322754
# time of calculating barcodes  0.0006611347198486328
# time finish calculating rank invariance 0.1331787109375
# total time for one elbow  0.14965391159057617
# elbow [34, 5]
# seconds of building a simplex tree 0.015132904052734375
# time of calculating barcodes  0.0008909702301025391
# time finish calculating rank invariance 0.14417600631713867
# total time for one elbow  0.16019988059997559
# elbow [34, 6]
# seconds of building a simplex tree 0.014242172241210938
# time of calculating barcodes  0.0009448528289794922
# time finish calculating rank invariance 0.13655495643615723
# total time for one elbow  0.15174198150634766
# elbow [34, 7]
# seconds of building a simplex tree 0.015294075012207031
# time of calculating barcodes  0.0008058547973632812
# time finish calculating rank invariance 0.16281604766845703
# total time for one elbow  0.17891597747802734
# elbow [34, 8]
# seconds of building a simplex tree 0.01848292350769043
# time of calculating barcodes  0.000637054443359375
# time finish calculating rank invariance 0.14808416366577148
# total time for one elbow  0.1672041416168213
# elbow [34, 9]
# seconds of building a simplex tree 0.014784097671508789
# time of calculating barcodes  0.0006339550018310547
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_h/svzdzphj0bd1v97t0py01b3w0000gn/T/ipykernel_4479/939568708.py in <module>
#      52                 [ri,rj,rk,rl]=[grid_start[0],grid_start[1],grid_end[0],grid_end[1]]
#      53                 #print("[ri,rj,rk,rl]=",[ri,rj,rk,rl])
# ---> 54                 rank_inv[ri,rj,rk,rl]=compute_rk(ri,rj,rk,rl,barcodes,rank_dim)
#      55         ri_time = time.time()
#      56         print("time finish calculating rank invariance",ri_time-bc_time)
#
# /var/folders/_h/svzdzphj0bd1v97t0py01b3w0000gn/T/ipykernel_4479/3083785593.py in compute_rk(i, j, k, l, barcodes, rank_dim)
#      35         elif(barcode[0]==1):
#      36             if(barcode[1][0]<=s_1 and barcode[1][1]>t_1):
# ---> 37                 rank1_inv = rank1_inv + 1
#      38     if(rank_dim==0):
#      39         return rank0_inv
#
# KeyboardInterrupt:

# %%
#Now it's rank0_invariance
np.save("./result/rank"+str(rank_dim)+"_invariance_for_"+file_name,rank_inv)
"""
for i in range(x_range+1):
    for j in range(y_range+1):
        for k in range(i,x_range+1):
            for l in range(j,y_range+1):
                print("rank(({0},{1}),({2},{3}))={4}".format(i,j,k,l,int(rank_inv[i,j,k,l])))
"""

# %% [markdown]
# ## compute multiplicity

# %%
#
#m((i,j),(k,l))
def multp(rank, i,j,k,l):
    if(i<0 or j<0 or k>rank.shape[1] or l>rank.shape[0]):   
        return 0
    
    res = rank[i,j,k,l]
    #print("res=",res)
    if(k+1<rank.shape[0]):
        #print("rank[i,j,k+1,l]=",rank[i,j,k+1,l])
        res -= rank[i,j,k+1,l]
        #print("res=",res)
    if(l+1<rank.shape[1]):
        #print("rank[i,j,k,l+1]=",rank[i,j,k,l+1])
        res -= rank[i,j,k,l+1]
        #print("res=",res)
    if(k+1<rank.shape[0] and l+1<rank.shape[1]):
        #print("rank[i,j,k+1,l+1]=",rank[i,j,k+1,l+1])
        res += rank[i,j,k+1,l+1]
        #print("res=",res)
    #print("=================multp(({0},{1}),({2},{3}))={4}===================".format(i,j,k,l,res))
    return res
    

def compute_R_S_incl_excl(rank):
    multiplicity = np.zeros_like(rank)
    for i in range(rank.shape[0]):
        for j in range(rank.shape[1]):
            for k in range(i,rank.shape[0]):
                for l in range(j,rank.shape[1]):
                    m = multp(rank,i,j,k,l)-multp(rank,i-1,j,k,l)-multp(rank,i,j-1,k,l)+multp(rank,i-1,j-1,k,l)
                    if(m!=0):
                        multiplicity[i,j,k,l] = m
    return multiplicity

# %%
rank_inv.shape

# %%
m = compute_R_S_incl_excl(rank_inv)

np.save("./result/rank"+str(rank_dim)+"_multiplicity_for_"+file_name,m)

# %% [markdown]
# ### Draw grid for multiplicity

# %%
data = np.ones((x_range,y_range)) * np.nan

fig, ax = plt.subplots(1, 1, figsize=(100,100),tight_layout=True)
for x in range(x_range+1):
    ax.axvline(x, lw=1, color='k', zorder=5) # Horizontal 
for y in range(y_range+1):
    ax.axhline(y, lw=1, color='k', zorder=5) # Ordinate
print(m.shape)

for i in range(m.shape[0]):
    for j in range(m.shape[1]):
        for k in range(i,m.shape[0]):
            for l in range(j,m.shape[1]):
                if(m[i,j,k,l]):
                    print("m(({0},{1}),({2},{3}))={4}".format(i,j,k,l,int(m[i,j,k,l])))
                if(m[i,j,k,l]>0):
                    if(i==k and j==l):
                        ax.plot([i, k], [j, l],'bo', linestyle="-")
                    elif(i==k):
                        ax.plot([i+0.08, k+0.08], [j, l],'bv', linestyle="-")
                    elif(j==l):
                        ax.plot([i, k], [j+0.08, l+0.08],'bv',linestyle="-")
                    else:  
                        ax.plot([i, k], [j, l],'bv', linestyle="-")
                if(m[i,j,k,l]<0):
                    if(i==k and j==l):
                        ax.plot([i, k], [j, l],'ro', linestyle="-")
                    elif(i==k):
                        ax.plot([i-0.08, k-0.08], [j, l],'rv', linestyle="-")
                    elif(j==l):
                        ax.plot([i, k], [j-0.08, l-0.08],'rv', linestyle="-")
                    else:  
                        ax.plot([i, k], [j, l], 'rv', linestyle="-")

ax.imshow(data, interpolation='none', extent=[-1,x_range+1, -1, y_range+1], zorder=0)

#ax.axis('off')
