# %% [markdown]
# # It's the quantization version

# %%
from IPython.display import Image
from os import chdir
import numpy as np
import tables as tb
import gudhi as gd
import matplotlib.pyplot as plt
import matplotlib
import time

# %%
# read the file
file_name = "function_rips_with_threshold_1000_1"
rank_dim = 0

simplices = []
vertice_id = 0
i = 0

x_values = []
y_values = []

for line in open("../cgta_paper_2021/function_rips/"+file_name+".scc"):
    if(line[0]!='#'):
        
        if(i<=1):
            i=i+1
            continue
            
        elif(i==2):
            rank_num=[] # sizes of generating sets
            for j in line.split():
                rank_num.append(int(j))
            i=i+1
            rank_num=rank_num[:-1]
            print("rank_num=",rank_num)
        else:
            block = line.split(';')
            grid = block[0].split()
            grid_x = float(grid[0])
            grid_y = float(grid[1])
            #grid_x = int(float(grid[0])*20)
            #grid_y = int(float(grid[1])*20)
            x_values.append(grid_x)
            y_values.append(grid_y)
            
            
            if len(block)>1:
                face = block[1].split()
                for j in range(len(face)):
                    face[j] = int(face[j])
                simplices.append([grid_x,grid_y,face])
                
            else:
                simplices.append([grid_x,grid_y,[vertice_id]])
                vertice_id += 1
            i=i+1   


simplex_tree = []
start_id=0
for i in range(len(rank_num)-1,-1,-1):
    simplices_i=[]
    for j in range(len(simplices)-start_id-rank_num[i],len(simplices)-start_id):
        simplices_i.append(simplices[j])
    start_id += rank_num[i]
    simplex_tree.append(simplices_i)


#transform face number to vertex number
for i in range(1,len(simplex_tree)):
    for j in range(len(simplex_tree[i])):
        simplex = simplex_tree[i][j]
        face = simplex[2]
        vertices=[]
        for face_id in face:
            vert = simplex_tree[i-1][face_id][2]
            for vert_id in vert:
                if vert_id not in vertices:
                    vertices.append(vert_id)
        simplex_tree[i][j][2]=vertices



## To verify the data structur
## simplices contain all the information we need
#print("the simplex tree:")
#for i in range(len(simplex_tree)):
#    for simplex in simplex_tree[i]:
#        print(simplex)
# Out:
# rank_num= [447, 347, 181, 50]

# %%
x_min=min(x_values)
y_min=min(y_values)
x_length = float(max(x_values)-x_min)
y_length = float(max(y_values)-y_min)

print("x_length=",x_length)
print("y_length=",y_length)
# Out:
# x_length= 0.7492297875079013
# y_length= 1.67101010952827

# %%
x_range = 19
y_range = 19

end_point=[x_range,y_range]
print("end_point ",end_point)

x_interval = x_length/x_range
y_interval = y_length/y_range

simplex_tree_integer=simplex_tree

for i in range(len(simplex_tree_integer)):
    for j in range(len(simplex_tree_integer[i])):
        #print("[i,j]",[i,j])
        if(x_interval==0):
            simplex_tree_integer[i][j][0]=0
        else:
            simplex_tree_integer[i][j][0] = round((simplex_tree[i][j][0]-x_min)/x_interval)
            
        if(y_interval==0):
            simplex_tree_integer[i][j][1]=0
        else:
            simplex_tree_integer[i][j][1] = round((simplex_tree[i][j][1]-y_min)/y_interval)
        #print("time of change value",end_change-start_change)
        
#for i in range(len(simplex_tree_integer)):
#    for simplex in simplex_tree_integer[i]:
#        print(simplex)
# Out:
# end_point  [19, 19]

# %% [markdown]
# ## Compute rank invariant

# %%
def create_stair(elbow, end_point):
    # stair a path passing through the elbow.
    stair = []
    
    if(elbow[0]==0 or elbow[1]==end_point[1]):
        for i in range(end_point[1]+1):
            stair.append([0,i])
        for j in range(1,end_point[0]+1):
            stair.append([j,i])
    else:
        for i in range(elbow[1]+1):
            stair.append([0,i])   # i=0
        for j in range(elbow[0]):
            stair.append([j+1,i]) # j=0
        for k in range(i+1, end_point[1]+1):
            stair.append([j+1,k]) # k=2,3
        for l in range(j+2, end_point[0]+1):
            stair.append([l,k])
    return stair

def compute_rk(i,j,k,l,barcodes,rank_dim):
# This function computes the value rank(s,t) where s=(i,j) and t = (k,l)
    if(i>k or j>l):
        return 0
    
    s_1 = i + j
    t_1 = k + l
    rank0_inv = 0
    rank1_inv = 0

    for barcode in barcodes:
        if(barcode[0]==0):
            if(barcode[1][0]<=s_1 and barcode[1][1]>t_1):
                rank0_inv = rank0_inv + 1
        elif(barcode[0]==1):
            if(barcode[1][0]<=s_1 and barcode[1][1]>t_1):
                rank1_inv = rank1_inv + 1
    if(rank_dim==0):
        return rank0_inv
    elif(rank_dim==1):
        return rank1_inv

# %%
def proj_grid_to_path(simplex, elbow, x_range, y_range):
    x = simplex[0]
    y = simplex[1]
    x0 = elbow[0]
    y0 = elbow[1]

    if((x==0 and y<=y0) or (y==y0 and x<=x0) or (y>=y0 and x==x0) or (y==y_range and x>=x0)):
        proj_p=[x,y]
    elif(x<=x0 and y<=y0):
        proj_p= [x,y0]
    elif(x<=x0 and y>=y0):
        proj_p= [x0,y]
    else:
        proj_p= [x,y_range]
    return proj_p

# %%
rank_inv = np.array(np.zeros((x_range+1,y_range+1,x_range+1,y_range+1)))

st = gd.SimplexTree()

#loop for all the elbows
for i in range(x_range+1):
    for j in range(y_range+1):
        elbow = [i,j]
        print("elbow",elbow)
        start_time=time.time()
        #print("time: start building a simplex tree",time.time())
        stair = create_stair(elbow, end_point)
        end_stair=time.time()
        print("time of creating a stair is ",end_stair-start_time,"s")

        # Build the simplex tree
        for ii in range(len(simplex_tree_integer)): #4
            for jj in range(len(simplex_tree_integer[ii])): #[37961, 36515, 20524, 5000]  
                start_loop = time.time()
                simplex = simplex_tree_integer[ii][jj]
                start_grid_id=time.time()
                proj_p = proj_grid_to_path(simplex, elbow, x_range, y_range)
                filtration_value=proj_p[0]+proj_p[1]
                if((st.insert(simplex[2], filtration = filtration_value))==False):
                    st.assign_filtration(simplex[2], filtration = filtration_value)
                
                end_loop = time.time()
                        
        st_time=time.time()                
        print("time of building a simplex tree",st_time-start_time,"s")
        #print("simplices ",st.num_simplices())
        #print("vertices ", st.num_vertices())
        
        #st_gen = st.get_filtration() 
        #for splx in st_gen :
        #    print(splx)
        
        barcodes = st.persistence()
        bc_time = time.time()
        print("time of calculating barcodes ",bc_time-st_time,"s")

        rank_inv_tmp = np.zeros_like(rank_inv)
        
        for barcode in barcodes:
            if(barcode[0]==rank_dim):
                barcode_sid = int(barcode[1][0])
                barcode_eid = barcode[1][1]
                if(barcode_eid>x_range+y_range+2):
                    barcode_eid = x_range+y_range+1
                barcode_eid = int(barcode_eid)

                bar_start_time=time.time()

                for r_s in range(barcode_sid,barcode_eid):#dubug for repeat sum
                    for r_e in range(r_s, barcode_eid):
                        rank_inv_tmp[stair[r_s][0],stair[r_s][1],stair[r_e][0],stair[r_e][1]]+=1 
                bar_end_time=time.time()
                
        rank_inv_tmp[rank_inv>0]=0
        
        rank_inv = rank_inv + rank_inv_tmp
        ri_time = time.time()
        print("time of calculating rank invariance",ri_time-bc_time,"s")
        print("total time for one elbow ",ri_time-start_time,"s")
# Out:
# elbow [0, 0]
# time of creating a stair is  1.3828277587890625e-05 s
# time of building a simplex tree 0.0030269622802734375 s
# time of calculating barcodes  0.0009729862213134766 s
# time of calculating rank invariance 0.005836009979248047 s
# total time for one elbow  0.009835958480834961 s
# elbow [0, 1]
# time of creating a stair is  1.6927719116210938e-05 s
# time of building a simplex tree 0.004809856414794922 s
# time of calculating barcodes  0.00780487060546875 s
# time of calculating rank invariance 0.009960412979125977 s
# total time for one elbow  0.02257513999938965 s
# elbow [0, 2]
# time of creating a stair is  1.6927719116210938e-05 s
# time of building a simplex tree 0.0038650035858154297 s
# time of calculating barcodes  0.0009450912475585938 s
# time of calculating rank invariance 0.00869297981262207 s
# total time for one elbow  0.013503074645996094 s
# elbow [0, 3]
# time of creating a stair is  1.3113021850585938e-05 s
# time of building a simplex tree 0.0026891231536865234 s
# time of calculating barcodes  0.0008499622344970703 s
# time of calculating rank invariance 0.00527501106262207 s
# total time for one elbow  0.008814096450805664 s
# elbow [0, 4]
# time of creating a stair is  1.5020370483398438e-05 s
# time of building a simplex tree 0.002763032913208008 s
# time of calculating barcodes  0.0008358955383300781 s
# time of calculating rank invariance 0.005012989044189453 s
# total time for one elbow  0.008611917495727539 s
# elbow [0, 5]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.0025038719177246094 s
# time of calculating barcodes  0.0007402896881103516 s
# time of calculating rank invariance 0.005020856857299805 s
# total time for one elbow  0.008265018463134766 s
# elbow [0, 6]
# time of creating a stair is  1.1205673217773438e-05 s
# time of building a simplex tree 0.0024213790893554688 s
# time of calculating barcodes  0.0006248950958251953 s
# time of calculating rank invariance 0.005079030990600586 s
# total time for one elbow  0.00812530517578125 s
# elbow [0, 7]
# time of creating a stair is  1.1205673217773438e-05 s
# time of building a simplex tree 0.002382993698120117 s
# time of calculating barcodes  0.0007851123809814453 s
# time of calculating rank invariance 0.0049479007720947266 s
# total time for one elbow  0.008116006851196289 s
# elbow [0, 8]
# time of creating a stair is  1.1682510375976562e-05 s
# time of building a simplex tree 0.002445697784423828 s
# time of calculating barcodes  0.000614166259765625 s
# time of calculating rank invariance 0.004882097244262695 s
# total time for one elbow  0.007941961288452148 s
# elbow [0, 9]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.0023941993713378906 s
# time of calculating barcodes  0.0006148815155029297 s
# time of calculating rank invariance 0.005243062973022461 s
# total time for one elbow  0.008252143859863281 s
# elbow [0, 10]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.0024111270904541016 s
# time of calculating barcodes  0.0006017684936523438 s
# time of calculating rank invariance 0.00506901741027832 s
# total time for one elbow  0.008081912994384766 s
# elbow [0, 11]
# time of creating a stair is  1.3113021850585938e-05 s
# time of building a simplex tree 0.002452850341796875 s
# time of calculating barcodes  0.0006170272827148438 s
# time of calculating rank invariance 0.005192995071411133 s
# total time for one elbow  0.008262872695922852 s
# elbow [0, 12]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.

# time of creating a stair is  1.1920928955078125e-05 s
# time of building a simplex tree 0.003332853317260742 s
# time of calculating barcodes  0.0014200210571289062 s
# time of calculating rank invariance 0.003290891647338867 s
# total time for one elbow  0.008043766021728516 s
# elbow [7, 2]
# time of creating a stair is  1.3828277587890625e-05 s
# time of building a simplex tree 0.0030188560485839844 s
# time of calculating barcodes  0.0014848709106445312 s
# time of calculating rank invariance 0.0065991878509521484 s
# total time for one elbow  0.011102914810180664 s
# elbow [7, 3]
# time of creating a stair is  1.2874603271484375e-05 s
# time of building a simplex tree 0.0025207996368408203 s
# time of calculating barcodes  0.001608133316040039 s
# time of calculating rank invariance 0.004538774490356445 s
# total time for one elbow  0.008667707443237305 s
# elbow [7, 4]
# time of creating a stair is  1.2159347534179688e-05 s
# time of building a simplex tree 0.0024352073669433594 s
# time of calculating barcodes  0.001283884048461914 s
# time of calculating rank invariance 0.00463104248046875 s
# total time for one elbow  0.008350133895874023 s
# elbow [7, 5]
# time of creating a stair is  1.3828277587890625e-05 s
# time of building a simplex tree 0.0024328231811523438 s
# time of calculating barcodes  0.0012161731719970703 s
# time of calculating rank invariance 0.0032126903533935547 s
# total time for one elbow  0.006861686706542969 s
# elbow [7, 6]
# time of creating a stair is  1.3113021850585938e-05 s
# time of building a simplex tree 0.0024230480194091797 s
# time of calculating barcodes  0.0013239383697509766 s
# time of calculating rank invariance 0.0044171810150146484 s
# total time for one elbow  0.008164167404174805 s
# elbow [7, 7]
# time of creating a stair is  1.2874603271484375e-05 s
# time of building a simplex tree 0.002407073974609375 s
# time of calculating barcodes  0.000993967056274414 s
# time of calculating rank invariance 0.003931760787963867 s
# total time for one elbow  0.007332801818847656 s
# elbow [7, 8]
# time of creating a stair is  1.5020370483398438e-05 s
# time of building a simplex tree 0.0026810169219970703 s
# time of calculating barcodes  0.0012798309326171875 s
# time of calculating rank invariance 0.0041751861572265625 s
# total time for one elbow  0.00813603401184082 s
# elbow [7, 9]
# time of creating a stair is  1.1920928955078125e-05 s
# time of building a simplex tree 0.0024378299713134766 s
# time of calculating barcodes  0.0013461112976074219 s
# time of calculating rank invariance 0.0046389102935791016 s
# total time for one elbow  0.0084228515625 s
# elbow [7, 10]
# time of creating a stair is  1.3113021850585938e-05 s
# time of building a simplex tree 0.0024361610412597656 s
# time of calculating barcodes  0.0013246536254882812 s
# time of calculating rank invariance 0.003787994384765625 s
# total time for one elbow  0.007548809051513672 s
# elbow [7, 11]
# time of creating a stair is  1.5974044799804688e-05 s
# time of building a simplex tree 0.0028128623962402344 s
# time of calculating barcodes  0.0012350082397460938 s
# time of calculating rank invariance 0.003860950469970703 s
# total time for one elbow  0.007908821105957031 s
# elbow [7, 12]
# time of creating a stair is  1.3113021850585938e-05 s
# time of building a simplex tree 0.0024061203002929688 s
# time of calculating barcodes  0.0008950233459472656 s
# time of calculating rank invariance 0.004614830017089844 s
# total time for one elbow  0.007915973663330078 s
# elbow [7, 13]
# time of creating a stair is  1.3113021850585938e-05 s
# time of building a simplex tree 0.0026350021362304688 s
# time of calculating barcodes  0.0013229846954345703 s
# time of calculating rank invariance 0.004433155059814453 s
# total time for one elbow  0.008391141891479492 s
# elbow [7, 14]
# time of creating a stair is  1.1920928955078125e-05 s
# time of building a simplex tree 0.0025539398193359375 s
# time of calculating barcodes  0.0018649101257324219 s
# time of calculating rank invariance 0.004573345184326172 s
# total time for one elbow  0.008992195129394531 s
# elbow [7, 15]
# time of creating a stair is  1.52587890625e-05 s
# time of building a simplex tree 0.0024590492248535156 s
# time of calculating barcodes  0.0011630058288574219 s
# time of calculating rank invariance 0.004663944244384766 s
# total time for one elbow  0.008285999298095703 s
# elbow [7, 16]
# time of creating a stair is  1.2159347534179688e-05 s
# time of building a simplex tree 0.0025300979614257812 s
# time of calculating barcodes  0.003281831741333008 s
# time of calculating rank invariance 0.005980968475341797 s
# total time for one elbow  0.011792898178100586 s
# elbow [7, 17]
# time of creating a stair is  1.2874603271484375e-05 s
# time of building a simplex tree 0.0024690628051757812 s
# time of calculating barcodes  0.0014140605926513672 s
# time of calculating rank invariance 0.00618290901184082 s
# total time for one elbow  0.010066032409667969 s
# elbow [7, 18]
# time of creating a stair is  1.52587890625e-05 s
# time of building a simplex tree 0.0029230117797851562 s
# time of calculating barcodes  0.0015721321105957031 s
# time of calculating rank invariance 0.005258083343505859 s
# total time for one elbow  0.009753227233886719 s
# elbow [7, 19]
# time of creating a stair is  1.1205673217773438e-05 s
# time of building a simplex tree 0.0024290084838867188 s
# time of calculating barcodes  0.0015380382537841797 s
# time of calculating rank invariance 0.007334232330322266 s
# total time for one elbow  0.011301279067993164 s
# elbow [8, 0]
# time of creating a stair is  1.3113021850585938e-05 s
# time of building a simplex tree 0.002791166305541992 s
# time of calculating barcodes  0.0012199878692626953 s
# time of calculating rank invariance 0.004564046859741211 s
# total time for one elbow  0.008575201034545898 s
# elbow [8, 1]
# time of creating a stair is  1.3828277587890625e-05 s
# time of building a simplex tree 0.0030601024627685547 s
# time of calculating barcodes  0.0014357566833496094 s
# time of calculating rank invariance 0.004006147384643555 s
# total time for one elbow  0.008502006530761719 s
# elbow [8, 2]
# time of creating a stair is  1.3113021850585938e-05 s
# time of building a simplex tree 0.0024178028106689453 s
# time of calculating barcodes  0.0012271404266357422 s
# time of calculating rank invariance 0.003910064697265625 s
# total time for one elbow  0.0075550079345703125 s
# elbow [8, 3]
# time of creating a stair is  1.3828277587890625e-05 s
# time of building a simplex tree 0.0031418800354003906 s
# time of calculating barcodes  0.0013480186462402344 s
# time of calculating rank invariance 0.003983974456787109 s
# total time for one elbow  0.008473873138427734 s
# elbow [8, 4]
# time of creating a stair is  1.5735626220703125e-05 s
# time of building a simplex tree 0.002599954605102539 s
# time of calculating barcodes  0.0010209083557128906 s
# time of calculating rank invariance 0.005464076995849609 s
# total time for one elbow  0.009084939956665039 s
# elbow [8, 5]
# time of creating a stair is  1.2874603271484375e-05 s
# time of building a simplex tree 0.0031549930572509766 s
# time of calculating barcodes  0.0007028579711914062 s
# time of calculating rank invariance 0.002286195755004883 s
# total time for one elbow  0.006144046783447266 s
# elbow [8, 6]
# time of creating a stair is  1.1920928955078125e-05 s
# time of building a simplex tree 0.002398967742919922 s
# time of calculating barcodes  0.0006067752838134766 s
# time of calculating rank invariance 0.002481222152709961 s
# total time for one elbow  0.005486965179443359 s
# elbow [8, 7]
# time of creating a stair is  1.1920928955078125e-05 s
# time of building a simplex tree 0.002756834030151367 s
# time of calculating barcodes  0.0009250640869140625 s
# time of calculating rank invariance 0.00316619873046875 s
# total time for one elbow  0.00684809684753418 s
# elbow [8, 8]
# time of creating a stair is  4.887580871582031e-05 s
# time of building a simplex tree 0.0025000572204589844 s
# ...
# time of building a simplex tree 0.0026209354400634766 s
# time of calculating barcodes  0.0013186931610107422 s
# time of calculating rank invariance 0.0038602352142333984 s
# total time for one elbow  0.007799863815307617 s
# elbow [17, 5]
# time of creating a stair is  1.2159347534179688e-05 s
# time of building a simplex tree 0.0027120113372802734 s
# time of calculating barcodes  0.0017061233520507812 s
# time of calculating rank invariance 0.0037059783935546875 s
# total time for one elbow  0.008124113082885742 s
# elbow [17, 6]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.

# time of creating a stair is  1.1920928955078125e-05 s
# time of building a simplex tree 0.002479076385498047 s
# time of calculating barcodes  0.0007410049438476562 s
# time of calculating rank invariance 0.0015208721160888672 s
# total time for one elbow  0.00474095344543457 s
# elbow [18, 3]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.002408742904663086 s
# time of calculating barcodes  0.0008442401885986328 s
# time of calculating rank invariance 0.002129077911376953 s
# total time for one elbow  0.005382061004638672 s
# elbow [18, 4]
# time of creating a stair is  1.1920928955078125e-05 s
# time of building a simplex tree 0.0024280548095703125 s
# time of calculating barcodes  0.00061798095703125 s
# time of calculating rank invariance 0.002154111862182617 s
# total time for one elbow  0.00520014762878418 s
# elbow [18, 5]
# time of creating a stair is  1.4066696166992188e-05 s
# time of building a simplex tree 0.0025043487548828125 s
# time of calculating barcodes  0.0008597373962402344 s
# time of calculating rank invariance 0.0021851062774658203 s
# total time for one elbow  0.005549192428588867 s
# elbow [18, 6]
# time of creating a stair is  1.1205673217773438e-05 s
# time of building a simplex tree 0.002459287643432617 s
# time of calculating barcodes  0.0006127357482910156 s
# time of calculating rank invariance 0.002081155776977539 s
# total time for one elbow  0.005153179168701172 s
# elbow [18, 7]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.002432107925415039 s
# time of calculating barcodes  0.0007369518280029297 s
# time of calculating rank invariance 0.002087831497192383 s
# total time for one elbow  0.0052568912506103516 s
# elbow [18, 8]
# time of creating a stair is  1.1920928955078125e-05 s
# time of building a simplex tree 0.0024809837341308594 s
# time of calculating barcodes  0.0006289482116699219 s
# time of calculating rank invariance 0.0020987987518310547 s
# total time for one elbow  0.005208730697631836 s
# elbow [18, 9]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.0027320384979248047 s
# time of calculating barcodes  0.0007569789886474609 s
# time of calculating rank invariance 0.0021619796752929688 s
# total time for one elbow  0.005650997161865234 s
# elbow [18, 10]
# time of creating a stair is  9.775161743164062e-06 s
# time of building a simplex tree 0.002404928207397461 s
# time of calculating barcodes  0.0007691383361816406 s
# time of calculating rank invariance 0.0024518966674804688 s
# total time for one elbow  0.00562596321105957 s
# elbow [18, 11]
# time of creating a stair is  1.2874603271484375e-05 s
# time of building a simplex tree 0.002610921859741211 s
# time of calculating barcodes  0.0007491111755371094 s
# time of calculating rank invariance 0.0024628639221191406 s
# total time for one elbow  0.005822896957397461 s
# elbow [18, 12]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.0026700496673583984 s
# time of calculating barcodes  0.0007538795471191406 s
# time of calculating rank invariance 0.0026869773864746094 s
# total time for one elbow  0.0061109066009521484 s
# elbow [18, 13]
# time of creating a stair is  1.2159347534179688e-05 s
# time of building a simplex tree 0.0025360584259033203 s
# time of calculating barcodes  0.0006198883056640625 s
# time of calculating rank invariance 0.0026700496673583984 s
# total time for one elbow  0.005825996398925781 s
# elbow [18, 14]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.0024330615997314453 s
# time of calculating barcodes  0.0007219314575195312 s
# time of calculating rank invariance 0.0026760101318359375 s
# total time for one elbow  0.005831003189086914 s
# elbow [18, 15]
# time of creating a stair is  1.0013580322265625e-05 s
# time of building a simplex tree 0.002413034439086914 s
# time of calculating barcodes  0.0007340908050537109 s
# time of calculating rank invariance 0.003000974655151367 s
# total time for one elbow  0.006148099899291992 s
# elbow [18, 16]
# time of creating a stair is  1.1920928955078125e-05 s
# time of building a simplex tree 0.0024569034576416016 s
# time of calculating barcodes  0.0006229877471923828 s
# time of calculating rank invariance 0.002819061279296875 s
# total time for one elbow  0.005898952484130859 s
# elbow [18, 17]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.0025331974029541016 s
# time of calculating barcodes  0.0007369518280029297 s
# time of calculating rank invariance 0.003062009811401367 s
# total time for one elbow  0.0063321590423583984 s
# elbow [18, 18]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.002452850341796875 s
# time of calculating barcodes  0.0006191730499267578 s
# time of calculating rank invariance 0.0032739639282226562 s
# total time for one elbow  0.006345987319946289 s
# elbow [18, 19]
# time of creating a stair is  1.0013580322265625e-05 s
# time of building a simplex tree 0.0023970603942871094 s
# time of calculating barcodes  0.0010998249053955078 s
# time of calculating rank invariance 0.0060269832611083984 s
# total time for one elbow  0.009523868560791016 s
# elbow [19, 0]
# time of creating a stair is  1.2159347534179688e-05 s
# time of building a simplex tree 0.002543210983276367 s
# time of calculating barcodes  0.0013020038604736328 s
# time of calculating rank invariance 0.0020759105682373047 s
# total time for one elbow  0.005921125411987305 s
# elbow [19, 1]
# time of creating a stair is  1.621246337890625e-05 s
# time of building a simplex tree 0.003041982650756836 s
# time of calculating barcodes  0.0008840560913085938 s
# time of calculating rank invariance 0.0018868446350097656 s
# total time for one elbow  0.005812883377075195 s
# elbow [19, 2]
# time of creating a stair is  1.3828277587890625e-05 s
# time of building a simplex tree 0.0024690628051757812 s
# time of calculating barcodes  0.001088857650756836 s
# time of calculating rank invariance 0.0022552013397216797 s
# total time for one elbow  0.005813121795654297 s
# elbow [19, 3]
# time of creating a stair is  3.1948089599609375e-05 s
# time of building a simplex tree 0.0025861263275146484 s
# time of calculating barcodes  0.0008478164672851562 s
# time of calculating rank invariance 0.0022268295288085938 s
# total time for one elbow  0.0056607723236083984 s
# elbow [19, 4]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.0024139881134033203 s
# time of calculating barcodes  0.0009541511535644531 s
# time of calculating rank invariance 0.002490997314453125 s
# total time for one elbow  0.0058591365814208984 s
# elbow [19, 5]
# time of creating a stair is  1.1205673217773438e-05 s
# time of building a simplex tree 0.002439260482788086 s
# time of calculating barcodes  0.0009288787841796875 s
# time of calculating rank invariance 0.0023870468139648438 s
# total time for one elbow  0.005755186080932617 s
# elbow [19, 6]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.0024449825286865234 s
# time of calculating barcodes  0.0007030963897705078 s
# time of calculating rank invariance 0.002317667007446289 s
# total time for one elbow  0.00546574592590332 s
# elbow [19, 7]
# time of creating a stair is  1.1205673217773438e-05 s
# time of building a simplex tree 0.002639293670654297 s
# time of calculating barcodes  0.0007178783416748047 s
# time of calculating rank invariance 0.002307891845703125 s
# total time for one elbow  0.0056650638580322266 s
# elbow [19, 8]
# time of creating a stair is  1.430511474609375e-05 s
# time of building a simplex tree 0.0024442672729492188 s
# time of calculating barcodes  0.0010318756103515625 s
# time of calculating rank invariance 0.002460002899169922 s
# total time for one elbow  0.005936145782470703 s
# elbow [19, 9]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.0024509429931640625 s
# time of calculating barcodes  0.0008141994476318359 s
# time of calculating rank invariance 0.002663850784301758 s
# total time for one elbow  0.005928993225097656 s
# elbow [19, 10]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.0024480819702148438 s
# time of calculating barcodes  0.0006959438323974609 s
# time of calculating rank invariance 0.002794027328491211 s
# total time for one elbow  0.005938053131103516 s
# elbow [19, 11]
# time of creating a stair is  2.9325485229492188e-05 s
# time of building a simplex tree 0.002573251724243164 s
# time of calculating barcodes  0.0008409023284912109 s
# time of calculating rank invariance 0.002875089645385742 s
# total time for one elbow  0.006289243698120117 s
# elbow [19, 12]
# time of creating a stair is  1.2159347534179688e-05 s
# time of building a simplex tree 0.002480030059814453 s
# time of calculating barcodes  0.0008401870727539062 s
# time of calculating rank invariance 0.0026895999908447266 s
# total time for one elbow  0.006009817123413086 s
# elbow [19, 13]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.0024499893188476562 s
# time of calculating barcodes  0.0008881092071533203 s
# time of calculating rank invariance 0.0029349327087402344 s
# total time for one elbow  0.006273031234741211 s
# elbow [19, 14]
# time of creating a stair is  1.2874603271484375e-05 s
# time of building a simplex tree 0.0024499893188476562 s
# time of calculating barcodes  0.0008268356323242188 s
# time of calculating rank invariance 0.0029871463775634766 s
# total time for one elbow  0.0062639713287353516 s
# elbow [19, 15]
# time of creating a stair is  1.0013580322265625e-05 s
# time of building a simplex tree 0.002463102340698242 s
# time of calculating barcodes  0.0008287429809570312 s
# time of calculating rank invariance 0.003088235855102539 s
# total time for one elbow  0.0063800811767578125 s
# elbow [19, 16]
# time of creating a stair is  1.3113021850585938e-05 s
# time of building a simplex tree 0.0025091171264648438 s
# time of calculating barcodes  0.0008339881896972656 s
# time of calculating rank invariance 0.0030260086059570312 s
# total time for one elbow  0.006369113922119141 s
# elbow [19, 17]
# time of creating a stair is  1.0728836059570312e-05 s
# time of building a simplex tree 0.0027310848236083984 s
# time of calculating barcodes  0.0007157325744628906 s
# time of calculating rank invariance 0.003492116928100586 s
# total time for one elbow  0.006938934326171875 s
# elbow [19, 18]
# time of creating a stair is  1.1682510375976562e-05 s
# time of building a simplex tree 0.002547025680541992 s
# time of calculating barcodes  0.0008356571197509766 s
# time of calculating rank invariance 0.00339508056640625 s
# total time for one elbow  0.006777763366699219 s
# elbow [19, 19]
# time of creating a stair is  1.0967254638671875e-05 s
# time of building a simplex tree 0.002412080764770508 s
# time of calculating barcodes  0.0010218620300292969 s
# time of calculating rank invariance 0.0050811767578125 s
# total time for one elbow  0.008515119552612305 s

# %%
#Now it's rank0_invariance
#np.save("./result/rank"+str(rank_dim)+"_invariance_for_"+file_name,rank_inv)

#for i in range(x_range+1):
#    for j in range(y_range+1):
#        for k in range(i,x_range+1):
#            for l in range(j,y_range+1):
#                if(rank_inv[i,j,k,l]):
#                    print("rank(({0},{1}),({2},{3}))={4}".format(i,j,k,l,int(rank_inv[i,j,k,l])))

# %% [markdown]
# ## compute multiplicity

# %%
#
#m((i,j),(k,l))
def multp(rank, i,j,k,l):
    if(i<0 or j<0 or k>rank.shape[1] or l>rank.shape[0]):   
        return 0
    
    res = rank[i,j,k,l]
    if(k+1<rank.shape[0]):
        res -= rank[i,j,k+1,l]
    if(l+1<rank.shape[1]):
        res -= rank[i,j,k,l+1]
    if(k+1<rank.shape[0] and l+1<rank.shape[1]):
        res += rank[i,j,k+1,l+1]
        
    return res
    

def compute_R_S_incl_excl(rank):
    multiplicity = np.zeros_like(rank)

    for i in range(rank.shape[0]):
        for j in range(rank.shape[1]):
            for k in range(i,rank.shape[0]):
                for l in range(j,rank.shape[1]):
                    m = multp(rank,i,j,k,l)-multp(rank,i-1,j,k,l)-multp(rank,i,j-1,k,l)+multp(rank,i-1,j-1,k,l)
                    if(m!=0):
                        multiplicity[i,j,k,l] = m
    return multiplicity

# %%
m_start_time = time.time()
m = compute_R_S_incl_excl(rank_inv)

for i in range(m.shape[0]):
    for j in range(m.shape[1]):
        for k in range(i,m.shape[0]):
            for l in range(j,m.shape[1]):
                m_element = multp(rank_inv,i,j,k,l)-multp(rank_inv,i-1,j,k,l)-multp(rank_inv,i,j-1,k,l)+multp(rank_inv,i-1,j-1,k,l)
                if(m_element!=0):
                    m[i,j,k,l] = m_element


m_end_time = time.time()
print("time of calculating multiplicity:",m_end_time-m_start_time,"s")
# Out:
# time of calculating multiplicity: 0.5762119293212891 s

# %% [markdown]
# ### Draw grid for multiplicity

# %%
data = np.ones((x_range,y_range)) * np.nan

fig, ax = plt.subplots(1, 1, figsize=(5,5),tight_layout=True)
for x in range(x_range+1):
    ax.axvline(x, lw=1, color='k', zorder=5) # Horizontal 
for y in range(y_range+1):
    ax.axhline(y, lw=1, color='k', zorder=5) # Ordinate
print(m.shape)

for i in range(m.shape[0]):
    for j in range(m.shape[1]):
        for k in range(i,m.shape[0]):
            for l in range(j,m.shape[1]):
                if(m[i,j,k,l]):
                    print("m(({0},{1}),({2},{3}))={4}".format(i,j,k,l,int(m[i,j,k,l])))
                if(m[i,j,k,l]>0):
                    if(i==k and j==l):
                        ax.plot([i, k], [j, l],'bo', linestyle="-")
                    elif(i==k):
                        ax.plot([i+0.08, k+0.08], [j, l],'bv', linestyle="-")
                    elif(j==l):
                        ax.plot([i, k], [j+0.08, l+0.08],'bv',linestyle="-")
                    else:  
                        ax.plot([i, k], [j, l],'bv', linestyle="-")
                if(m[i,j,k,l]<0):
                    if(i==k and j==l):
                        ax.plot([i, k], [j, l],'ro', linestyle="-")
                    elif(i==k):
                        ax.plot([i-0.08, k-0.08], [j, l],'rv', linestyle="-")
                    elif(j==l):
                        ax.plot([i, k], [j-0.08, l-0.08],'rv', linestyle="-")
                    else:  
                        ax.plot([i, k], [j, l], 'rv', linestyle="-")

ax.imshow(data, interpolation='none', extent=[-1,x_range+1, -1, y_range+1], zorder=0)

#ax.axis('off')
# Out:
# (20, 20, 20, 20)
# m((0,0),(19,19))=1
# m((0,3),(1,19))=1
# m((0,3),(3,4))=-1
# m((0,3),(3,19))=1
# m((0,3),(6,4))=1
# m((0,3),(9,18))=-1
# m((0,3),(9,19))=1
# m((0,3),(15,18))=-1
# m((0,3),(15,19))=1
# m((0,3),(16,6))=-1
# m((0,3),(16,18))=1
# m((0,3),(19,6))=1
# m((0,3),(19,18))=1
# m((0,5),(2,19))=1
# m((0,7),(2,19))=2
# m((0,10),(2,19))=2
# m((0,10),(7,18))=-1
# m((0,10),(7,19))=1
# m((0,10),(17,18))=1
# m((0,15),(3,19))=1
# m((0,17),(4,19))=1
# m((0,17),(13,19))=1
# m((0,19),(4,19))=5
# m((0,19),(5,19))=5
# m((0,19),(6,19))=2
# m((0,19),(7,19))=3
# m((0,19),(8,19))=6
# m((0,19),(9,19))=2
# m((0,19),(10,19))=1
# m((0,19),(11,19))=4
# m((0,19),(12,19))=2
# m((0,19),(13,19))=2
# m((0,19),(19,19))=4
